# %%
from hamp_pred.src.predictor import Predictor
from hamp_pred.src.predictor_config import DEFAULT_CONF, PredictionConfig,SEQ_ENCODING_EXTERNAL
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from Bio import SeqIO
import tensorflow as tf
from external.SequenceEncoding.SequenceEncoding import SequenceEncoding, get_dict
from hamp_pred.src.input_prep.encode import OneHotEncoderSeq, RadianEncoder, MixedEncoder, MultiEncoder
from hamp_pred.src.input_prep.prepare_sequence import MultiChainOperator, SeqWindow
from hamp_pred.src.models.common.models import BaseConvolutionalWrapper, BaseLinearWrapper
from hamp_pred.src.input_prep.encode import RadiousPhobosEncoder
from keras.utils.vis_utils import plot_model
from Bio.PDB.PDBParser import PDBParser
import os
import matplotlib.pyplot as plt
from hamp_pred.src.output_analysis.visual import reg_plot

# %%
data = pd.read_pickle('../data/input/full_alpha_data.p')
val_ids = set(data[data['class'] == 'val'].index)
val_data = data.loc[val_ids]
test_data = pd.read_pickle('../data/input/full_pdb_hamp.p')
test_data.rename(columns={'seq1':'n_seq', 'seq2':'c_seq', 'n_list':'n_crick_mut', 'c_list':'c_crick_mut'}, inplace=True)
mutants_ids = ['5jeq.pdb',
            '5jef.pdb',
            '3zrv.pdb',
            '2lfs.pdb',
            '3zrw.pdb',
            '3zcc.pdb',
            '2l7i.pdb', '2y20.pdb', '2y21.pdb', '2y0q.pdb',
                    
            '3lnr.pdb', 
                    '4i44.pdb', '4i3m.pdb'

           
           ]
test_mutants, test_wild = test_data.drop(mutants_ids), test_data.loc[mutants_ids]
# Out:
# /tmp/ipykernel_32143/308110718.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   val_data = data.loc[val_ids]

# %% [markdown]
# # Aligned helix rotation

# %%
operator = MultiChainOperator(MultiEncoder([RadiousPhobosEncoder(), OneHotEncoderSeq()]), SeqWindow(11, 11), RadianEncoder(100),  SeqWindow(11, 11, null_char=[[0]]),
                                      parallel=True)
model_conf = model_config = {
    'activation': 'tanh',
    'norm': True,
    'n_layers': 1,
    'kernel_sizes': (3, 5, 7),
    'lstm': 2,
    'dense': 1,
    'reshape_out': False,
    'epochs': 100
}
conf = PredictionConfig(BaseConvolutionalWrapper, operator, model_conf)
mod = Predictor('hamp_rot', config=conf)

# %% [markdown]
# ## Validation

# %%
val_results = mod.predict(val_data, is_test=True)
print(f"RMSE_SEQ: {val_results['mse_seq']**0.5}\nRMSE_POS: {val_results['mse_pos']**0.5}")
# Out:
# 2022-10-02 03:38:54.697513: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-02 03:38:55.697060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7185 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2022-10-02 03:38:55.697946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 7161 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1
# 2022-10-02 03:38:58.206767: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8204
# 2022-10-02 03:38:58.462674: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-10-02 03:38:58.463313: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-10-02 03:38:58.463359: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-10-02 03:38:58.464169: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-10-02 03:38:58.464314: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 1/1 [==============================] - 2s 2s/step
# RMSE_SEQ: 10.667673976173521
# RMSE_POS: 26.212131134366835

# %%
reg_plot(np.array(val_results['true_mean_rot']), np.array(val_results['pred_mean_rot']))
# Out:
# <AxesSubplot:title={'center':'Predictions for data set'}, xlabel='Predicted', ylabel='True'>

# %% [markdown]
# ## Test Wild

# %%
test_wild_results = mod.predict(test_wild, is_test=True)
print(f"RMSE_SEQ: {test_wild_results['mse_seq']**0.5}\nRMSE_POS: {test_wild_results['mse_pos']**0.5}")
# Out:
# 1/1 [==============================] - 1s 1s/step
# RMSE_SEQ: 11.371559626381012
# RMSE_POS: 25.82778593269335

# %%
reg_plot(test_wild_results['true_mean_rot'], test_wild_results['pred_mean_rot'], title='Predictions for WT HAMPs (no mutants)')
# Out:
# <AxesSubplot:title={'center':'Predictions for WT HAMPs (no mutants)'}, xlabel='Predicted', ylabel='True'>

# %% [markdown]
# ## Test Mutants

# %%
test_mutants_results = mod.predict(test_mutants, is_test=True)
print(f"RMSE_SEQ: {test_mutants_results['mse_seq']**0.5}\nRMSE_POS: {test_mutants_results['mse_pos']**0.5}")
# Out:
# 1/1 [==============================] - 1s 1s/step
# RMSE_SEQ: 13.719141792550104
# RMSE_POS: 44.07636904697611

# %%
reg_plot(test_mutants_results['true_mean_rot'], test_mutants_results['pred_mean_rot'], title='Predictions for Mutants')
# Out:
# <AxesSubplot:title={'center':'Predictions for Mutants'}, xlabel='Predicted', ylabel='True'>

# %% [markdown]
# # Full length helix rotation

# %%
pred = Predictor('hamp_crick_single_sequence')

# %% [markdown]
# ## Validation

# %%
val_results_full = pred.predict(val_data, is_test=True)
print(f"RMSE_SEQ: {val_results_full['mse_seq']**0.5}\nRMSE_POS: {val_results_full['mse_pos']**0.5}")
# Out:
# 2022-10-02 03:44:55.417152: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-02 03:44:56.323092: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7185 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2022-10-02 03:44:56.323610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 7161 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1
# 2022-10-02 03:44:59.153328: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8204
# 2022-10-02 03:44:59.405588: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-10-02 03:44:59.406175: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-10-02 03:44:59.406224: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-10-02 03:44:59.407041: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-10-02 03:44:59.407175: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 1/1 [==============================] - 3s 3s/step
# /home/users/awinski/HAMPred/hamp_pred/src/input_prep/encode.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array([np.array(x) for x in labels])
# /home/users/awinski/HAMPred/hamp_pred/src/input_prep/encode.py:183: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ret = np.asarray(res)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 val_results_full = pred.predict(val_data, is_test=True)
#       2 print(f"RMSE_SEQ: {val_results_full['mse_seq']**0.5}\nRMSE_POS: {val_results_full['mse_pos']**0.5}")
#
# File ~/HAMPred/hamp_pred/src/predictor.py:54, in Predictor.predict(self, data, with_model, **kwargs)
#      52 if kwargs.get('is_test'):
#      53     conf['is_test'] = True
# ---> 54 result = predict.run(data, conf)
#      55 if kwargs.get('is_test'):
#      56     conf['is_test'] = False
#
# File ~/HAMPred/hamp_pred/src/models/hamp_crick_single_sequence/predict.py:42, in run(sequences, config)
#      40 data['predicted_rotation'] = data['detected_helices_crick'].apply(lambda x: adjuster.get_rotation(*x))
#      41 if config.get('is_test', False):
# ---> 42     return tester.get_metrics(test_data, data)
#      43 return (data,) + results[1:]
#
# File ~/HAMPred/hamp_pred/src/models/hamp_crick_single_sequence/test.py:29, in Tester.get_metrics(self, test, prediction)
#      28 def get_metrics(self, test, prediction):
# ---> 29     rot = super().get_metrics(test, prediction)
#      30     crick = self.get_crick_f1(test, prediction)
#      31     return {**rot, **crick}
#
# File ~/HAMPred/hamp_pred/src/models/hamp_rot/test.py:28, in Tester.get_metrics(self, test, prediction)
#      26     mean_pred.append(np.mean(pred))
#      27     pos_rot_pred.extend(pred)
# ---> 28 metrics = {'mse_seq': Metrics.mse(mean_rot_true, mean_pred, ignore=self.ignored_vals),
#      29            'mse_pos': Metrics.mse(pos_rot_true, pos_rot_pred, ignore=self.ignored_vals),
#      30            'true_pos_rot': pos_rot_true,
#      31            'pred_pos_rot': pos_rot_pred,
#      32            'true_mean_rot': mean_rot_true,
#      33            'pred_mean_rot': mean_pred}
#      34 return self._to_arrays(metrics)
#
# File ~/HAMPred/hamp_pred/src/output_analysis/metrics.py:10, in Metrics.mse(tr, exp, ignore)
#       8         continue
#       9     sm += (t - e) ** 2
# ---> 10 res = sm / len(exp)
#      11 return res if isinstance(res, float) else res[0]
#
# ZeroDivisionError: division by zero

# %%
reg_plot(val_results_full['true_mean_rot'], val_results_full['pred_mean_rot'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 reg_plot(val_results_full['true_mean_rot'], val_results_full['pred_mean_rot'])
#
# NameError: name 'val_results_full' is not defined

# %% [markdown]
# ## Test Wild

# %%
test_wild_results_full = pred.predict(test_wild, is_test=True)
print(f"RMSE_SEQ: {test_wild_results_full['mse_seq']**0.5}\nRMSE_POS: {test_wild_results_full['mse_pos']**0.5}")
# Out:
# 1/1 [==============================] - 1s 1s/step
# /home/users/awinski/HAMPred/hamp_pred/src/input_prep/encode.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array([np.array(x) for x in labels])
# /home/users/awinski/HAMPred/hamp_pred/src/input_prep/encode.py:183: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ret = np.asarray(res)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 test_wild_results_full = pred.predict(test_wild, is_test=True)
#       2 print(f"RMSE_SEQ: {test_wild_results_full['mse_seq']**0.5}\nRMSE_POS: {test_wild_results_full['mse_pos']**0.5}")
#
# File ~/HAMPred/hamp_pred/src/predictor.py:54, in Predictor.predict(self, data, with_model, **kwargs)
#      52 if kwargs.get('is_test'):
#      53     conf['is_test'] = True
# ---> 54 result = predict.run(data, conf)
#      55 if kwargs.get('is_test'):
#      56     conf['is_test'] = False
#
# File ~/HAMPred/hamp_pred/src/models/hamp_crick_single_sequence/predict.py:42, in run(sequences, config)
#      40 data['predicted_rotation'] = data['detected_helices_crick'].apply(lambda x: adjuster.get_rotation(*x))
#      41 if config.get('is_test', False):
# ---> 42     return tester.get_metrics(test_data, data)
#      43 return (data,) + results[1:]
#
# File ~/HAMPred/hamp_pred/src/models/hamp_crick_single_sequence/test.py:29, in Tester.get_metrics(self, test, prediction)
#      28 def get_metrics(self, test, prediction):
# ---> 29     rot = super().get_metrics(test, prediction)
#      30     crick = self.get_crick_f1(test, prediction)
#      31     return {**rot, **crick}
#
# File ~/HAMPred/hamp_pred/src/models/hamp_rot/test.py:28, in Tester.get_metrics(self, test, prediction)
#      26     mean_pred.append(np.mean(pred))
#      27     pos_rot_pred.extend(pred)
# ---> 28 metrics = {'mse_seq': Metrics.mse(mean_rot_true, mean_pred, ignore=self.ignored_vals),
#      29            'mse_pos': Metrics.mse(pos_rot_true, pos_rot_pred, ignore=self.ignored_vals),
#      30            'true_pos_rot': pos_rot_true,
#      31            'pred_pos_rot': pos_rot_pred,
#      32            'true_mean_rot': mean_rot_true,
#      33            'pred_mean_rot': mean_pred}
#      34 return self._to_arrays(metrics)
#
# File ~/HAMPred/hamp_pred/src/output_analysis/metrics.py:10, in Metrics.mse(tr, exp, ignore)
#       8         continue
#       9     sm += (t - e) ** 2
# ---> 10 res = sm / len(exp)
#      11 return res if isinstance(res, float) else res[0]
#
# ZeroDivisionError: division by zero

# %%
reg_plot(test_wild_results_full['true_mean_rot'], test_wild_results_full['pred_mean_rot'])
# Out:
# <AxesSubplot:title={'center':'Predictions for data set'}, xlabel='Predicted', ylabel='True'>

# %% [markdown]
# ## Test Mutants

# %%
test_mutants_results_full = pred.predict(test_mutants, is_test=True)
print(f"RMSE_SEQ: {test_mutants_results_full['mse_seq']**0.5}\nRMSE_POS: {test_mutants_results_full['mse_pos']**0.5}")
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafc03cc9d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# RMSE_SEQ: 13.719141792550104
# RMSE_POS: 44.07636904697611

# %%
reg_plot(test_mutants_results_full['true_mean_rot'], test_mutants_results_full['pred_mean_rot'], title='Predictions for Mutants')
# Out:
# <AxesSubplot:title={'center':'Predictions for Mutants'}, xlabel='Predicted', ylabel='True'>
