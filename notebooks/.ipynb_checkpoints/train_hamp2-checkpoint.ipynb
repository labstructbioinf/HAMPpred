# %%
from ma_predictor.src.predictor import Predictor
from ma_predictor.src.predictor_config import DEFAULT_CONF, PredictionConfig,SEQ_ENCODING_EXTERNAL
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from Bio import SeqIO
from external.SequenceEncoding.SequenceEncoding import SequenceEncoding, get_dict
from ma_predictor.src.input_prep.encode import OneHotEncoderSeq, RadianEncoder, MixedEncoder
from ma_predictor.src.input_prep.prepare_sequence import MultiChainOperator, SeqWindow
from ma_predictor.src.models.common.models import BaseConvolutionalWrapper, BaseLinearWrapper
from keras.utils.vis_utils import plot_model
from Bio.PDB.PDBParser import PDBParser
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare data

# %%
DATA_DIR = '/home/users/sdunin/calc/TCST'
data = f'{DATA_DIR}/offline_data/cache/af2_true_full.features.p'
data = pd.read_pickle(data)
data['n_seq'] = data['n_seq'].apply(lambda x: x[1:-1])
data['c_seq'] = data['c_seq'].apply(lambda x: x[1:-1])
data['train_seq'] = data.apply(lambda x: x['n_seq'] + x['c_seq'], axis=1)
val_ids = set(data[data['class'] == 'val'].index)
idx = list(data.index)

# %% [markdown]
# ## Train and validate

# %%
mod = Predictor('hamp_rot', config=DEFAULT_CONF)
trained = mod.train(data, ids=idx, val_ids=val_ids)
# Out:
# Encoded 1/4305 sequences
# Encoded 2/4305 sequences
# Encoded 3/4305 sequences
# Encoded 4/4305 sequences
# Encoded 5/4305 sequences
# Encoded 6/4305 sequences
# Encoded 7/4305 sequences
# Encoded 8/4305 sequences
# Encoded 9/4305 sequences
# Encoded 10/4305 sequences
# Encoded 11/4305 sequences
# Encoded 12/4305 sequences
# Encoded 13/4305 sequences
# Encoded 14/4305 sequences
# Encoded 15/4305 sequences
# Encoded 16/4305 sequences
# Encoded 17/4305 sequences
# Encoded 18/4305 sequences
# Encoded 19/4305 sequences
# Encoded 20/4305 sequences
# Encoded 21/4305 sequences
# Encoded 22/4305 sequences
# Encoded 23/4305 sequences
# Encoded 24/4305 sequences
# Encoded 25/4305 sequences
# Encoded 26/4305 sequences
# Encoded 27/4305 sequences
# Encoded 28/4305 sequences
# Encoded 29/4305 sequences
# Encoded 30/4305 sequences
# Encoded 31/4305 sequences
# Encoded 32/4305 sequences
# Encoded 33/4305 sequences
# Encoded 34/4305 sequences
# Encoded 35/4305 sequences
# Encoded 36/4305 sequences
# Encoded 37/4305 sequences
# Encoded 38/4305 sequences
# Encoded 39/4305 sequences
# Encoded 40/4305 sequences
# Encoded 41/4305 sequences
# Encoded 42/4305 sequences
# Encoded 43/4305 sequences
# Encoded 44/4305 sequences
# Encoded 45/4305 sequences
# Encoded 46/4305 sequences
# Encoded 47/4305 sequences
# Encoded 48/4305 sequences
# Encoded 49/4305 sequences
# Encoded 50/4305 sequences
# Encoded 51/4305 sequences
# Encoded 52/4305 sequences
# Encoded 53/4305 sequences
# Encoded 54/4305 sequences
# Encoded 55/4305 sequences
# Encoded 56/4305 sequences
# Encoded 57/4305 sequences
# Encoded 58/4305 sequences
# Encoded 59/4305 sequences
# Encoded 60/4305 sequences
# Encoded 61/4305 sequences
# Encoded 62/4305 sequences
# Encoded 63/4305 sequences
# Encoded 64/4305 sequences
# Encoded 65/4305 sequences
# Encoded 66/4305 sequences
# Encoded 67/4305 sequences
# Encoded 68/4305 sequences
# Encoded 69/4305 sequences
# Encoded 70/4305 sequences
# Encoded 71/4305 sequences
# Encoded 72/4305 sequences
# Encoded 73/4305 sequences
# Encoded 74/4305 sequences
# Encoded 75/4305 sequences
# Encoded 76/4305 sequences
# Encoded 77/4305 sequences
# Encoded 78/4305 sequences
# Encoded 79/4305 sequences
# Encoded 80/4305 sequences
# Encoded 81/4305 sequences
# Encoded 82/4305 sequences
# Encoded 83/4305 sequences
# Encoded 84/4305 sequences
# Encoded 85/4305 sequences
# Encoded 86/4305 sequences
# Encoded 87/4305 sequences
# Encoded 88/4305 sequences
# Encoded 89/4305 sequences
# Encoded 90/4305 sequences
# Encoded 91/4305 sequences
# Encoded 92/4305 sequences
# Encoded 93/4305 sequences
# Encoded 94/4305 sequences
# Encoded 95/4305 sequences
# Encoded 96/4305 sequences
# Encoded 97/4305 sequences
# Encoded 98/4305 sequences
# Encoded 99/4305 sequences
# Encoded 100/4305 sequences
# Encoded 101/4305 sequences
# Encoded 102/4305 sequences
# Encoded 103/4305 sequences
# Encoded 104/4305 sequences
# Encoded 105/4305 sequences
# Encoded 106/4305 sequences
# Encoded 107/4305 sequences
# Encoded 108/4305 sequences
# Encoded 109/4305 sequences
# Encoded 110/4305 sequences
# Encoded 111/4305 sequences
# Encoded 112/4305 sequences
# Encoded 113/4305 sequences
# Encoded 114/4305 sequences
# Encoded 115/4305 sequences
# Encoded 116/4305 sequences
# Encoded 117/4305 sequences
# Encoded 118/4305 sequences
# Encoded 119/4305 sequences
# Encoded 120/4305 sequences
# Encoded 121/4305 sequences
# Encoded 122/4305 sequences
# Encoded 123/4305 sequences
# Encoded 124/4305 sequences
# Encoded 125/4305 sequences
# Encoded 126/4305 sequences
# Encoded 127/4305 sequences
# Encoded 128/4305 sequences
# Encoded 129/4305 sequences
# Encoded 130/4305 sequences
# Encoded 131/4305 sequences
# Encoded 132/4305 sequences
# Encoded 133/4305 sequences
# Encoded 134/4305 sequences
# Encoded 135/4305 sequences
# Encoded 136/4305 sequences
# Encoded 137/4305 sequences
# Encoded 138/4305 sequences
# Encoded 139/4305 sequences
# Encoded 140/4305 sequences
# Encoded 141/4305 sequences
# Encoded 142/4305 sequences
# Encoded 143/4305 sequences
# Encoded 144/4305 sequences
# Encoded 145/4305 sequences
# Encoded 146/4305 sequences
# Encoded 147/4305 sequences
# Encoded 148/4305 sequences
# Encoded 149/4305 sequences
# Encoded 150/4305 sequences
# Encoded 151/4305 sequences
# Encoded 152/4305 sequences
# Encoded 153/4305 sequences
# Encoded 154/4305 sequences
# Encoded 155/4305 sequences
# Encoded 156/4305 sequences
# Encoded 157/4305 sequences
# Encoded 158/4305 sequences
# Encoded 159/4305 sequences
# Encoded 160/4305 sequences
# Encoded 161/4305 sequences
# Encoded 162/4305 sequences
# Encoded 163/4305 sequences
# Encoded 164/4305 sequences
# Encoded 165/4305 sequences
# Encoded 166/4305 sequences
# Encoded 167/4305 sequences
# Encoded 168/4305 sequences
# Encoded 169/4305 sequences
# Encoded 170/4305 sequences
# Encoded 171/4305 sequences
# Encoded 172/4305 sequences
# Encoded 173/4305 sequences
# Encoded 174/4305 sequences
# Encoded 175/4305 sequences
# Encoded 176/4305 sequences
# Encoded 177/4305 sequences
# Encoded 178/4305 sequences
# Encoded 179/4305 sequences
# Encoded 180/4305 sequences
# Encoded 181/4305 sequences
# Encoded 182/4305 sequences
# Encoded 183/4305 sequences
# Encoded 184/4305 sequences
# Encoded 185/4305 sequences
# Encoded 186/4305 sequences
# Encoded 187/4305 sequences
# Encoded 188/4305 sequences
# Encoded 189/4305 sequences
# Encoded 190/4305 sequences
# Encoded 191/4305 sequences
# Encoded 192/4305 sequences
# Encoded 193/4305 sequences
# Encoded 194/4305 sequences
# Encoded 195/4305 sequences
# Encoded 196/4305 sequences
# Encoded 197/4305 sequences
# Encoded 198/4305 sequences
# Encoded 199/4305 sequences
# Encoded 200/4305 sequences
# Encoded 201/4305 sequences
# Encoded 202/4305 sequences
# Encoded 203/4305 sequences
# Encoded 204/4305 sequences
# Encoded 205/4305 sequences
# Encoded 206/4305 sequences
# Encoded 207/4305 sequences
# Encoded 208/4305 sequences
# Encoded 209/4305 sequences
# Encoded 210/4305 sequences
# Encoded 211/4305 sequences
# Encoded 212/4305 sequences
# Encoded 213/4305 sequences
# Encoded 214/4305 sequences
# Encoded 215/4305 sequences
# Encoded 216/4305 sequences
# Encoded 217/4305 sequences
# Encoded 218/4305 sequences
# Encoded 219/4305 sequences
# Encoded 220/4305 sequences
# Encoded 221/4305 sequences
# Encoded 222/4305 sequences
# Encoded 223/4305 sequences
# Encoded 224/4305 sequences
# Encoded 225/4305 sequences
# Encoded 226/4305 sequences
# Encoded 227/4305 sequences
# Encoded 228/4305 sequences
# Encoded 229/4305 sequences
# Encoded 230/4305 sequences
# Encoded 231/4305 sequences
# Encoded 232/4305 sequences
# Encoded 233/4305 sequences
# Encoded 234/4305 sequences
# Encoded 235/4305 sequences
# Encoded 236/4305 sequences
# Encoded 237/4305 sequences
# Encoded 238/4305 sequences
# Encoded 239/4305 sequences
# Encoded 240/4305 sequences
# Encoded 241/4305 sequences
# Encoded 242/4305 sequences
# Encoded 243/4305 sequences
# Encoded 244/4305 sequences
# Encoded 245/4305 sequences
# Encoded 246/4305 sequences
# Encoded 247/4305 sequences
# Encoded 248/4305 sequences
# Encoded 249/4305 sequences
# Encoded 250/4305 sequences
# Encoded 251/4305 sequences
# Encoded 252/4305 sequences
# Encoded 253/4305 sequences
# Encoded 254/4305 sequences
# Encoded 255/4305 sequences
# Encoded 256/4305 sequences
# Encoded 257/4305 sequences
# Encoded 258/4305 sequences
# Encoded 259/4305 sequences
# Encoded 260/4305 sequences
# Encoded 261/4305 sequences
# Encoded 262/4305 sequences
# Encoded 263/4305 sequences
# Encoded 264/4305 sequences
# Encoded 265/4305 sequences
# Encoded 266/4305 sequences
# Encoded 267/4305 sequences
# Encoded 268/4305 sequences
# Encoded 269/4305 sequences
# Encoded 270/4305 sequences
# Encoded 271/4305 sequences
# Encoded 272/4305 sequences
# Encoded 273/4305 sequences
# Encoded 274/4305 sequences
# Encoded 275/4305 sequences
# Encoded 276/4305 sequences
# Encoded 277/4305 sequences
# Encoded 278/4305 sequences
# Encoded 279/4305 sequences
# Encoded 280/4305 sequences
# Encoded 281/4305 sequences
# Encoded 282/4305 sequences
# Encoded 283/4305 sequences
# Encoded 284/4305 sequences
# Encoded 285/4305 sequences
# Encoded 286/4305 sequences
# Encoded 287/4305 sequences
# Encoded 288/4305 sequences
# Encoded 289/4305 sequences
# Encoded 290/4305 sequences
# Encoded 291/4305 sequences
# Encoded 292/4305 sequences
# Encoded 293/4305 sequences
# Encoded 294/4305 sequences
# Encoded 295/4305 sequences
# Encoded 296/4305 sequences
# Encoded 297/4305 sequences
# Encoded 298/4305 sequences
# Encoded 299/4305 sequences
# Encoded 300/4305 sequences
# Encoded 301/4305 sequences
# Encoded 302/4305 sequences
# Encoded 303/4305 sequences
# Encoded 304/4305 sequences
# Encoded 305/4305 sequences
# Encoded 306/4305 sequences
# Encoded 307/4305 sequences
# Encoded 308/4305 sequences
# Encoded 309/4305 sequences
# Encoded 310/4305 sequences
# Encoded 311/4305 sequences
# Encoded 312/4305 sequences
# Encoded 313/4305 sequences
# Encoded 314/4305 sequences
# Encoded 315/4305 sequences
# Encoded 316/4305 sequences
# Encoded 317/4305 sequences
# Encoded 318/4305 sequences
# Encoded 319/4305 sequences
# Encoded 320/4305 sequences
# Encoded 321/4305 sequences
# Encoded 322/4305 sequences
# Encoded 323/4305 sequences
# Encoded 324/4305 sequences
# Encoded 325/4305 sequences
# Encoded 326/4305 sequences
# Encoded 327/4305 sequences
# Encoded 328/4305 sequences
# Encoded 329/4305 sequences
# Encoded 330/4305 sequences
# Encoded 331/4305 sequences
# Encoded 332/4305 sequences
# Encoded 333/4305 sequences
# Encoded 334/4305 sequences
# Encoded 335/4305 sequences
# Encoded 336/4305 sequences
# Encoded 337/4305 sequences
# Encoded 338/4305 sequences
# Encoded 339/4305 sequences
# Encoded 340/4305 sequences
# Encoded 341/4305 sequences
# Encoded 342/4305 sequences
# Encoded 343/4305 sequences
# Encoded 344/4305 sequences
# Encoded 345/4305 sequences
# Encoded 346/4305 sequences
# Encoded 347/4305 sequences
# Encoded 348/4305 sequences
# Encoded 349/4305 sequences
# Encoded 350/4305 sequences
# Encoded 351/4305 sequences
# Encoded 352/4305 sequences
# Encoded 353/4305 sequences
# Encoded 354/4305 sequences
# Encoded 355/4305 sequences
# Encoded 356/4305 sequences
# Encoded 357/4305 sequences
# Encoded 358/4305 sequences
# Encoded 359/4305 sequences
# Encoded 360/4305 sequences
# Encoded 361/4305 sequences
# Encoded 362/4305 sequences
# Encoded 363/4305 sequences
# Encoded 364/4305 sequences
# Encoded 365/4305 sequences
# Encoded 366/4305 sequences
# Encoded 367/4305 sequences
# Encoded 368/4305 sequences
# Encoded 369/4305 sequences
# Encoded 370/4305 sequences
# Encoded 371/4305 sequences
# Encoded 372/4305 sequences
# Encoded 373/4305 sequences
# Encoded 374/4305 sequences
# Encoded 375/4305 sequences
# Encoded 376/4305 sequences
# Encoded 377/4305 sequences
# Encoded 378/4305 sequences
# Encoded 379/4305 sequences
# Encoded 380/4305 sequences
# Encoded 381/4305 sequences
# Encoded 382/4305 sequences
# Encoded 383/4305 sequences
# Encoded 384/4305 sequences
# Encoded 385/4305 sequences
# Encoded 386/4305 sequences
# Encoded 387/4305 sequences
# Encoded 388/4305 sequences
# Encoded 389/4305 sequences
# Encoded 390/4305 sequences
# Encoded 391/4305 sequences
# Encoded 392/4305 sequences
# Encoded 393/4305 sequences
# Encoded 394/4305 sequences
# Encoded 395/4305 sequences
# Encoded 396/4305 sequences
# Encoded 397/4305 sequences
# Encoded 398/4305 sequences
# Encoded 399/4305 sequences
# Encoded 400/4305 sequences
# Encoded 401/4305 sequences
# Encoded 402/4305 sequences
# Encoded 403/4305 sequences
# Encoded 404/4305 sequences
# Encoded 405/4305 sequences
# Encoded 406/4305 sequences
# Encoded 407/4305 sequences
# Encoded 408/4305 sequences
# Encoded 409/4305 sequences
# Encoded 410/4305 sequences
# Encoded 411/4305 sequences
# Encoded 412/4305 sequences
# Encoded 413/4305 sequences
# Encoded 414/4305 sequences
# Encoded 415/4305 sequences
# Encoded 416/4305 sequences
# Encoded 417/4305 sequences
# Encoded 418/4305 sequences
# Encoded 419/4305 sequences
# Encoded 420/4305 sequences
# Encoded 421/4305 sequences
# Encoded 422/4305 sequences
# Encoded 423/4305 sequences
# Encoded 424/4305 sequences
# Encoded 425/4305 sequences
# Encoded 426/4305 sequences
# Encoded 427/4305 sequences
# Encoded 428/4305 sequences
# Encoded 429/4305 sequences
# Encoded 430/4305 sequences
# Encoded 431/4305 sequences
# Encoded 432/4305 sequences
# Encoded 433/4305 sequences
# Encoded 434/4305 sequences
# Encoded 435/4305 sequences
# Encoded 436/4305 sequences
# Encoded 437/4305 sequences
# Encoded 438/4305 sequences
# Encoded 439/4305 sequences
# Encoded 440/4305 sequences
# Encoded 441/4305 sequences
# Encoded 442/4305 sequences
# Encoded 443/4305 sequences
# Encoded 444/4305 sequences
# Encoded 445/4305 sequences
# Encoded 446/4305 sequences
# Encoded 447/4305 sequences
# Encoded 448/4305 sequences
# Encoded 449/4305 sequences
# Encoded 450/4305 sequences
# Encoded 451/4305 sequences
# Encoded 452/4305 sequences
# Encoded 453/4305 sequences
# Encoded 454/4305 sequences
# Encoded 455/4305 sequences
# Encoded 456/4305 sequences
# Encoded 457/4305 sequences
# Encoded 458/4305 sequences
# Encoded 459/4305 sequences
# Encoded 460/4305 sequences
# Encoded 461/4305 sequences
# Encoded 462/4305 sequences
# Encoded 463/4305 sequences
# Encoded 464/4305 sequences
# Encoded 465/4305 sequences
# Encoded 466/4305 sequences
# Encoded 467/4305 sequences
# Encoded 468/4305 sequences
# Encoded 469/4305 sequences
# Encoded 470/4305 sequences
# Encoded 471/4305 sequences
# Encoded 472/4305 sequences
# Encoded 473/4305 sequences
# Encoded 474/4305 sequences
# Encoded 475/4305 sequences
# Encoded 476/4305 sequences
# Encoded 477/4305 sequences
# Encoded 478/4305 sequences
# Encoded 479/4305 sequences
# Encoded 480/4305 sequences
# Encoded 481/4305 sequences
# Encoded 482/4305 sequences
# Encoded 483/4305 sequences
# Encoded 484/4305 sequences
# Encoded 485/4305 sequences
# Encoded 486/4305 sequences
# Encoded 487/4305 sequences
# Encoded 488/4305 sequences
# Encoded 489/4305 sequences
# Encoded 490/4305 sequences
# Encoded 491/4305 sequences
# Encoded 492/4305 sequences
# Encoded 493/4305 sequences
# Encoded 494/4305 sequences
# Encoded 495/4305 sequences
# Encoded 496/4305 sequences
# Encoded 497/4305 sequences
# Encoded 498/4305 sequences
# Encoded 499/4305 sequences
# Encoded 500/4305 sequences
# Encoded 501/4305 sequences
# Encoded 502/4305 sequences
# Encoded 503/4305 sequences
# Encoded 504/4305 sequences
# Encoded 505/4305 sequences
# Encoded 506/4305 sequences
# Encoded 507/4305 sequences
# Encoded 508/4305 sequences
# Encoded 509/4305 sequences
# Encoded 510/4305 sequences
# Encoded 511/4305 sequences
# Encoded 512/4305 sequences
# Encoded 513/4305 sequences
# Encoded 514/4305 sequences
# Encoded 515/4305 sequences
# Encoded 516/4305 sequences
# Encoded 517/4305 sequences
# Encoded 518/4305 sequences
# Encoded 519/4305 sequences
# Encoded 520/4305 sequences
# Encoded 521/4305 sequences
# Encoded 522/4305 sequences
# Encoded 523/4305 sequences
# Encoded 524/4305 sequences
# Encoded 525/4305 sequences
# Encoded 526/4305 sequences
# Encoded 527/4305 sequences
# Encoded 528/4305 sequences
# Encoded 529/4305 sequences
# Encoded 530/4305 sequences
# Encoded 531/4305 sequences
# Encoded 532/4305 sequences
# Encoded 533/4305 sequences
# Encoded 534/4305 sequences
# Encoded 535/4305 sequences
# Encoded 536/4305 sequences
# Encoded 537/4305 sequences
# Encoded 538/4305 sequences
# Encoded 539/4305 sequences
# Encoded 540/4305 sequences
# Encoded 541/4305 sequences
# Encoded 542/4305 sequences
# Encoded 543/4305 sequences
# Encoded 544/4305 sequences
# Encoded 545/4305 sequences
# Encoded 546/4305 sequences
# Encoded 547/4305 sequences
# Encoded 548/4305 sequences
# Encoded 549/4305 sequences
# Encoded 550/4305 sequences
# Encoded 551/4305 sequences
# Encoded 552/4305 sequences
# Encoded 553/4305 sequences
# Encoded 554/4305 sequences
# Encoded 555/4305 sequences
# Encoded 556/4305 sequences
# Encoded 557/4305 sequences
# Encoded 558/4305 sequences
# Encoded 559/4305 sequences
# Encoded 560/4305 sequences
# Encoded 561/4305 sequences
# Encoded 562/4305 sequences
# Encoded 563/4305 sequences
# Encoded 564/4305 sequences
# Encoded 565/4305 sequences
# Encoded 566/4305 sequences
# Encoded 567/4305 sequences
# Encoded 568/4305 sequences
# Encoded 569/4305 sequences
# Encoded 570/4305 sequences
# Encoded 571/4305 sequences
# Encoded 572/4305 sequences
# Encoded 573/4305 sequences
# Encoded 574/4305 sequences
# Encoded 575/4305 sequences
# Encoded 576/4305 sequences
# Encoded 577/4305 sequences
# Encoded 578/4305 sequences
# Encoded 579/4305 sequences
# Encoded 580/4305 sequences
# Encoded 581/4305 sequences
# Encoded 582/4305 sequences
# Encoded 583/4305 sequences
# Encoded 584/4305 sequences
# Encoded 585/4305 sequences
# Encoded 586/4305 sequences
# Encoded 587/4305 sequences
# Encoded 588/4305 sequences
# Encoded 589/4305 sequences
# Encoded 590/4305 sequences
# Encoded 591/4305 sequences
# Encoded 592/4305 sequences
# Encoded 593/4305 sequences
# Encoded 594/4305 sequences
# Encoded 595/4305 sequences
# Encoded 596/4305 sequences
# Encoded 597/4305 sequences
# Encoded 598/4305 sequences
# Encoded 599/4305 sequences
# Encoded 600/4305 sequences
# Encoded 601/4305 sequences
# Encoded 602/4305 sequences
# Encoded 603/4305 sequences
# Encoded 604/4305 sequences
# Encoded 605/4305 sequences
# Encoded 606/4305 sequences
# Encoded 607/4305 sequences
# Encoded 608/4305 sequences
# Encoded 609/4305 sequences
# Encoded 610/4305 sequences
# Encoded 611/4305 sequences
# Encoded 612/4305 sequences
# Encoded 613/4305 sequences
# Encoded 614/4305 sequences
# Encoded 615/4305 sequences
# Encoded 616/4305 sequences
# Encoded 617/4305 sequences
# Encoded 618/4305 sequences
# Encoded 619/4305 sequences
# Encoded 620/4305 sequences
# Encoded 621/4305 sequences
# Encoded 622/4305 sequences
# Encoded 623/4305 sequences
# Encoded 624/4305 sequences
# Encoded 625/4305 sequences
# Encoded 626/4305 sequences
# Encoded 627/4305 sequences
# Encoded 628/4305 sequences
# Encoded 629/4305 sequences
# Encoded 630/4305 sequences
# Encoded 631/4305 sequences
# Encoded 632/4305 sequences
# Encoded 633/4305 sequences
# Encoded 634/4305 sequences
# Encoded 635/4305 sequences
# Encoded 636/4305 sequences
# Encoded 637/4305 sequences
# Encoded 638/4305 sequences
# Encoded 639/4305 sequences
# Encoded 640/4305 sequences
# Encoded 641/4305 sequences
# Encoded 642/4305 sequences
# Encoded 643/4305 sequences
# Encoded 644/4305 sequences
# Encoded 645/4305 sequences
# Encoded 646/4305 sequences
# Encoded 647/4305 sequences
# Encoded 648/4305 sequences
# Encoded 649/4305 sequences
# Encoded 650/4305 sequences
# Encoded 651/4305 sequences
# Encoded 652/4305 sequences
# Encoded 653/4305 sequences
# Encoded 654/4305 sequences
# Encoded 655/4305 sequences
# Encoded 656/4305 sequences
# Encoded 657/4305 sequences
# Encoded 658/4305 sequences
# Encoded 659/4305 sequences
# Encoded 660/4305 sequences
# Encoded 661/4305 sequences
# Encoded 662/4305 sequences
# Encoded 663/4305 sequences
# Encoded 664/4305 sequences
# Encoded 665/4305 sequences
# Encoded 666/4305 sequences
# Encoded 667/4305 sequences
# Encoded 668/4305 sequences
# Encoded 669/4305 sequences
# Encoded 670/4305 sequences
# Encoded 671/4305 sequences
# Encoded 672/4305 sequences
# Encoded 673/4305 sequences
# Encoded 674/4305 sequences
# Encoded 675/4305 sequences
# Encoded 676/4305 sequences
# Encoded 677/4305 sequences
# Encoded 678/4305 sequences
# Encoded 679/4305 sequences
# Encoded 680/4305 sequences
# Encoded 681/4305 sequences
# Encoded 682/4305 sequences
# Encoded 683/4305 sequences
# Encoded 684/4305 sequences
# Encoded 685/4305 sequences
# Encoded 686/4305 sequences
# Encoded 687/4305 sequences
# Encoded 688/4305 sequences
# Encoded 689/4305 sequences
# Encoded 690/4305 sequences
# Encoded 691/4305 sequences
# Encoded 692/4305 sequences
# Encoded 693/4305 sequences
# Encoded 694/4305 sequences
# Encoded 695/4305 sequences
# Encoded 696/4305 sequences
# Encoded 697/4305 sequences
# Encoded 698/4305 sequences
# Encoded 699/4305 sequences
# Encoded 700/4305 sequences
# Encoded 701/4305 sequences
# Encoded 702/4305 sequences
# Encoded 703/4305 sequences
# Encoded 704/4305 sequences
# Encoded 705/4305 sequences
# Encoded 706/4305 sequences
# Encoded 707/4305 sequences
# Encoded 708/4305 sequences
# Encoded 709/4305 sequences
# Encoded 710/4305 sequences
# Encoded 711/4305 sequences
# Encoded 712/4305 sequences
# Encoded 713/4305 sequences
# Encoded 714/4305 sequences
# Encoded 715/4305 sequences
# Encoded 716/4305 sequences
# Encoded 717/4305 sequences
# Encoded 718/4305 sequences
# Encoded 719/4305 sequences
# Encoded 720/4305 sequences
# Encoded 721/4305 sequences
# Encoded 722/4305 sequences
# Encoded 723/4305 sequences
# Encoded 724/4305 sequences
# Encoded 725/4305 sequences
# Encoded 726/4305 sequences
# Encoded 727/4305 sequences
# Encoded 728/4305 sequences
# Encoded 729/4305 sequences
# Encoded 730/4305 sequences
# Encoded 731/4305 sequences
# Encoded 732/4305 sequences
# Encoded 733/4305 sequences
# Encoded 734/4305 sequences
# Encoded 735/4305 sequences
# Encoded 736/4305 sequences
# Encoded 737/4305 sequences
# Encoded 738/4305 sequences
# Encoded 739/4305 sequences
# Encoded 740/4305 sequences
# Encoded 741/4305 sequences
# Encoded 742/4305 sequences
# Encoded 743/4305 sequences
# Encoded 744/4305 sequences
# Encoded 745/4305 sequences
# Encoded 746/4305 sequences
# Encoded 747/4305 sequences
# Encoded 748/4305 sequences
# Encoded 749/4305 sequences
# Encoded 750/4305 sequences
# Encoded 751/4305 sequences
# Encoded 752/4305 sequences
# Encoded 753/4305 sequences
# Encoded 754/4305 sequences
# Encoded 755/4305 sequences
# Encoded 756/4305 sequences
# Encoded 757/4305 sequences
# Encoded 758/4305 sequences
# Encoded 759/4305 sequences
# Encoded 760/4305 sequences
# Encoded 761/4305 sequences
# Encoded 762/4305 sequences
# Encoded 763/4305 sequences
# Encoded 764/4305 sequences
# Encoded 765/4305 sequences
# Encoded 766/4305 sequences
# Encoded 767/4305 sequences
# Encoded 768/4305 sequences
# Encoded 769/4305 sequences
# Encoded 770/4305 sequences
# Encoded 771/4305 sequences
# Encoded 772/4305 sequences
# Encoded 773/4305 sequences
# Encoded 774/4305 sequences
# Encoded 775/4305 sequences
# Encoded 776/4305 sequences
# Encoded 777/4305 sequences
# Encoded 778/4305 sequences
# Encoded 779/4305 sequences
# Encoded 780/4305 sequences
# Encoded 781/4305 sequences
# Encoded 782/4305 sequences
# Encoded 783/4305 sequences
# Encoded 784/4305 sequences
# Encoded 785/4305 sequences
# Encoded 786/4305 sequences
# Encoded 787/4305 sequences
# Encoded 788/4305 sequences
# Encoded 789/4305 sequences
# Encoded 790/4305 sequences
# Encoded 791/4305 sequences
# Encoded 792/4305 sequences
# Encoded 793/4305 sequences
# Encoded 794/4305 sequences
# Encoded 795/4305 sequences
# Encoded 796/4305 sequences
# Encoded 797/4305 sequences
# Encoded 798/4305 sequences
# Encoded 799/4305 sequences
# Encoded 800/4305 sequences
# Encoded 801/4305 sequences
# Encoded 802/4305 sequences
# Encoded 803/4305 sequences
# Encoded 804/4305 sequences
# Encoded 805/4305 sequences
# Encoded 806/4305 sequences
# Encoded 807/4305 sequences
# Encoded 808/4305 sequences
# Encoded 809/4305 sequences
# Encoded 810/4305 sequences
# Encoded 811/4305 sequences
# Encoded 812/4305 sequences
# Encoded 813/4305 sequences
# Encoded 814/4305 sequences
# Encoded 815/4305 sequences
# Encoded 816/4305 sequences
# Encoded 817/4305 sequences
# Encoded 818/4305 sequences
# Encoded 819/4305 sequences
# Encoded 820/4305 sequences
# Encoded 821/4305 sequences
# Encoded 822/4305 sequences
# Encoded 823/4305 sequences
# Encoded 824/4305 sequences
# Encoded 825/4305 sequences
# Encoded 826/4305 sequences
# Encoded 827/4305 sequences
# Encoded 828/4305 sequences
# Encoded 829/4305 sequences
# Encoded 830/4305 sequences
# Encoded 831/4305 sequences
# Encoded 832/4305 sequences
# Encoded 833/4305 sequences
# Encoded 834/4305 sequences
# Encoded 835/4305 sequences
# Encoded 836/4305 sequences
# Encoded 837/4305 sequences
# Encoded 838/4305 sequences
# Encoded 839/4305 sequences
# Encoded 840/4305 sequences
# Encoded 841/4305 sequences
# Encoded 842/4305 sequences
# Encoded 843/4305 sequences
# Encoded 844/4305 sequences
# Encoded 845/4305 sequences
# Encoded 846/4305 sequences
# Encoded 847/4305 sequences
# Encoded 848/4305 sequences
# Encoded 849/4305 sequences
# Encoded 850/4305 sequences
# Encoded 851/4305 sequences
# Encoded 852/4305 sequences
# Encoded 853/4305 sequences
# Encoded 854/4305 sequences
# Encoded 855/4305 sequences
# Encoded 856/4305 sequences
# Encoded 857/4305 sequences
# Encoded 858/4305 sequences
# Encoded 859/4305 sequences
# Encoded 860/4305 sequences
# Encoded 861/4305 sequences
# Encoded 862/4305 sequences
# Encoded 863/4305 sequences
# Encoded 864/4305 sequences
# Encoded 865/4305 sequences
# Encoded 866/4305 sequences
# Encoded 867/4305 sequences
# Encoded 868/4305 sequences
# Encoded 869/4305 sequences
# Encoded 870/4305 sequences
# Encoded 871/4305 sequences
# Encoded 872/4305 sequences
# Encoded 873/4305 sequences
# Encoded 874/4305 sequences
# Encoded 875/4305 sequences
# Encoded 876/4305 sequences
# Encoded 877/4305 sequences
# Encoded 878/4305 sequences
# Encoded 879/4305 sequences
# Encoded 880/4305 sequences
# Encoded 881/4305 sequences
# Encoded 882/4305 sequences
# Encoded 883/4305 sequences
# Encoded 884/4305 sequences
# Encoded 885/4305 sequences
# Encoded 886/4305 sequences
# Encoded 887/4305 sequences
# Encoded 888/4305 sequences
# Encoded 889/4305 sequences
# Encoded 890/4305 sequences
# Encoded 891/4305 sequences
# Encoded 892/4305 sequences
# Encoded 893/4305 sequences
# Encoded 894/4305 sequences
# Encoded 895/4305 sequences
# Encoded 896/4305 sequences
# Encoded 897/4305 sequences
# Encoded 898/4305 sequences
# Encoded 899/4305 sequences
# Encoded 900/4305 sequences
# Encoded 901/4305 sequences
# Encoded 902/4305 sequences
# Encoded 903/4305 sequences
# Encoded 904/4305 sequences
# Encoded 905/4305 sequences
# Encoded 906/4305 sequences
# Encoded 907/4305 sequences
# Encoded 908/4305 sequences
# Encoded 909/4305 sequences
# Encoded 910/4305 sequences
# Encoded 911/4305 sequences
# Encoded 912/4305 sequences
# Encoded 913/4305 sequences
# Encoded 914/4305 sequences
# Encoded 915/4305 sequences
# Encoded 916/4305 sequences
# Encoded 917/4305 sequences
# Encoded 918/4305 sequences
# Encoded 919/4305 sequences
# Encoded 920/4305 sequences
# Encoded 921/4305 sequences
# Encoded 922/4305 sequences
# Encoded 923/4305 sequences
# Encoded 924/4305 sequences
# Encoded 925/4305 sequences
# Encoded 926/4305 sequences
# Encoded 927/4305 sequences
# Encoded 928/4305 sequences
# Encoded 929/4305 sequences
# Encoded 930/4305 sequences
# Encoded 931/4305 sequences
# Encoded 932/4305 sequences
# Encoded 933/4305 sequences
# Encoded 934/4305 sequences
# Encoded 935/4305 sequences
# Encoded 936/4305 sequences
# Encoded 937/4305 sequences
# Encoded 938/4305 sequences
# Encoded 939/4305 sequences
# Encoded 940/4305 sequences
# Encoded 941/4305 sequences
# Encoded 942/4305 sequences
# Encoded 943/4305 sequences
# Encoded 944/4305 sequences
# Encoded 945/4305 sequences
# Encoded 946/4305 sequences
# Encoded 947/4305 sequences
# Encoded 948/4305 sequences
# Encoded 949/4305 sequences
# Encoded 950/4305 sequences
# Encoded 951/4305 sequences
# Encoded 952/4305 sequences
# Encoded 953/4305 sequences
# Encoded 954/4305 sequences
# Encoded 955/4305 sequences
# Encoded 956/4305 sequences
# Encoded 957/4305 sequences
# Encoded 958/4305 sequences
# Encoded 959/4305 sequences
# Encoded 960/4305 sequences
# Encoded 961/4305 sequences
# Encoded 962/4305 sequences
# Encoded 963/4305 sequences
# Encoded 964/4305 sequences
# Encoded 965/4305 sequences
# Encoded 966/4305 sequences
# Encoded 967/4305 sequences
# Encoded 968/4305 sequences
# Encoded 969/4305 sequences
# Encoded 970/4305 sequences
# Encoded 971/4305 sequences
# Encoded 972/4305 sequences
# Encoded 973/4305 sequences
# Encoded 974/4305 sequences
# Encoded 975/4305 sequences
# Encoded 976/4305 sequences
# Encoded 977/4305 sequences
# Encoded 978/4305 sequences
# Encoded 979/4305 sequences
# Encoded 980/4305 sequences
# Encoded 981/4305 sequences
# Encoded 982/4305 sequences
# Encoded 983/4305 sequences
# Encoded 984/4305 sequences
# Encoded 985/4305 sequences
# Encoded 986/4305 sequences
# Encoded 987/4305 sequences
# Encoded 988/4305 sequences
# Encoded 989/4305 sequences
# Encoded 990/4305 sequences
# Encoded 991/4305 sequences
# Encoded 992/4305 sequences
# Encoded 993/4305 sequences
# Encoded 994/4305 sequences
# Encoded 995/4305 sequences
# Encoded 996/4305 sequences
# Encoded 997/4305 sequences
# Encoded 998/4305 sequences
# Encoded 999/4305 sequences
# Encoded 1000/4305 sequences
# Encoded 1001/4305 sequences
# Encoded 1002/4305 sequences
# Encoded 1003/4305 sequences
# Encoded 1004/4305 sequences
# Encoded 1005/4305 sequences
# Encoded 1006/4305 sequences
# Encoded 1007/4305 sequences
# Encoded 1008/4305 sequences
# Encoded 1009/4305 sequences
# Encoded 1010/4305 sequences
# Encoded 1011/4305 sequences
# Encoded 1012/4305 sequences
# Encoded 1013/4305 sequences
# Encoded 1014/4305 sequences
# Encoded 1015/4305 sequences
# Encoded 1016/4305 sequences
# Encoded 1017/4305 sequences
# Encoded 1018/4305 sequences
# Encoded 1019/4305 sequences
# Encoded 1020/4305 sequences
# Encoded 1021/4305 sequences
# Encoded 1022/4305 sequences
# Encoded 1023/4305 sequences
# Encoded 1024/4305 sequences
# Encoded 1025/4305 sequences
# Encoded 1026/4305 sequences
# Encoded 1027/4305 sequences
# Encoded 1028/4305 sequences
# Encoded 1029/4305 sequences
# Encoded 1030/4305 sequences
# Encoded 1031/4305 sequences
# Encoded 1032/4305 sequences
# Encoded 1033/4305 sequences
# Encoded 1034/4305 sequences
# Encoded 1035/4305 sequences
# Encoded 1036/4305 sequences
# Encoded 1037/4305 sequences
# Encoded 1038/4305 sequences
# Encoded 1039/4305 sequences
# Encoded 1040/4305 sequences
# Encoded 1041/4305 sequences
# Encoded 1042/4305 sequences
# Encoded 1043/4305 sequences
# Encoded 1044/4305 sequences
# Encoded 1045/4305 sequences
# Encoded 1046/4305 sequences
# Encoded 1047/4305 sequences
# Encoded 1048/4305 sequences
# Encoded 1049/4305 sequences
# Encoded 1050/4305 sequences
# Encoded 1051/4305 sequences
# Encoded 1052/4305 sequences
# Encoded 1053/4305 sequences
# Encoded 1054/4305 sequences
# Encoded 1055/4305 sequences
# Encoded 1056/4305 sequences
# Encoded 1057/4305 sequences
# Encoded 1058/4305 sequences
# Encoded 1059/4305 sequences
# Encoded 1060/4305 sequences
# Encoded 1061/4305 sequences
# Encoded 1062/4305 sequences
# Encoded 1063/4305 sequences
# Encoded 1064/4305 sequences
# Encoded 1065/4305 sequences
# Encoded 1066/4305 sequences
# Encoded 1067/4305 sequences
# Encoded 1068/4305 sequences
# Encoded 1069/4305 sequences
# Encoded 1070/4305 sequences
# Encoded 1071/4305 sequences
# Encoded 1072/4305 sequences
# Encoded 1073/4305 sequences
# Encoded 1074/4305 sequences
# Encoded 1075/4305 sequences
# Encoded 1076/4305 sequences
# Encoded 1077/4305 sequences
# Encoded 1078/4305 sequences
# Encoded 1079/4305 sequences
# Encoded 1080/4305 sequences
# Encoded 1081/4305 sequences
# Encoded 1082/4305 sequences
# Encoded 1083/4305 sequences
# Encoded 1084/4305 sequences
# Encoded 1085/4305 sequences
# Encoded 1086/4305 sequences
# Encoded 1087/4305 sequences
# Encoded 1088/4305 sequences
# Encoded 1089/4305 sequences
# Encoded 1090/4305 sequences
# Encoded 1091/4305 sequences
# Encoded 1092/4305 sequences
# Encoded 1093/4305 sequences
# Encoded 1094/4305 sequences
# Encoded 1095/4305 sequences
# Encoded 1096/4305 sequences
# Encoded 1097/4305 sequences
# Encoded 1098/4305 sequences
# Encoded 1099/4305 sequences
# Encoded 1100/4305 sequences
# Encoded 1101/4305 sequences
# Encoded 1102/4305 sequences
# Encoded 1103/4305 sequences
# Encoded 1104/4305 sequences
# Encoded 1105/4305 sequences
# Encoded 1106/4305 sequences
# Encoded 1107/4305 sequences
# Encoded 1108/4305 sequences
# Encoded 1109/4305 sequences
# Encoded 1110/4305 sequences
# Encoded 1111/4305 sequences
# Encoded 1112/4305 sequences
# Encoded 1113/4305 sequences
# Encoded 1114/4305 sequences
# Encoded 1115/4305 sequences
# Encoded 1116/4305 sequences
# Encoded 1117/4305 sequences
# Encoded 1118/4305 sequences
# Encoded 1119/4305 sequences
# Encoded 1120/4305 sequences
# Encoded 1121/4305 sequences
# Encoded 1122/4305 sequences
# Encoded 1123/4305 sequences
# Encoded 1124/4305 sequences
# Encoded 1125/4305 sequences
# Encoded 1126/4305 sequences
# Encoded 1127/4305 sequences
# Encoded 1128/4305 sequences
# Encoded 1129/4305 sequences
# Encoded 1130/4305 sequences
# Encoded 1131/4305 sequences
# Encoded 1132/4305 sequences
# Encoded 1133/4305 sequences
# Encoded 1134/4305 sequences
# Encoded 1135/4305 sequences
# Encoded 1136/4305 sequences
# Encoded 1137/4305 sequences
# Encoded 1138/4305 sequences
# Encoded 1139/4305 sequences
# Encoded 1140/4305 sequences
# Encoded 1141/4305 sequences
# Encoded 1142/4305 sequences
# Encoded 1143/4305 sequences
# Encoded 1144/4305 sequences
# Encoded 1145/4305 sequences
# Encoded 1146/4305 sequences
# Encoded 1147/4305 sequences
# Encoded 1148/4305 sequences
# Encoded 1149/4305 sequences
# Encoded 1150/4305 sequences
# Encoded 1151/4305 sequences
# Encoded 1152/4305 sequences
# Encoded 1153/4305 sequences
# Encoded 1154/4305 sequences
# Encoded 1155/4305 sequences
# Encoded 1156/4305 sequences
# Encoded 1157/4305 sequences
# Encoded 1158/4305 sequences
# Encoded 1159/4305 sequences
# Encoded 1160/4305 sequences
# Encoded 1161/4305 sequences
# Encoded 1162/4305 sequences
# Encoded 1163/4305 sequences
# Encoded 1164/4305 sequences
# Encoded 1165/4305 sequences
# Encoded 1166/4305 sequences
# Encoded 1167/4305 sequences
# Encoded 1168/4305 sequences
# Encoded 1169/4305 sequences
# Encoded 1170/4305 sequences
# Encoded 1171/4305 sequences
# Encoded 1172/4305 sequences
# Encoded 1173/4305 sequences
# Encoded 1174/4305 sequences
# Encoded 1175/4305 sequences
# Encoded 1176/4305 sequences
# Encoded 1177/4305 sequences
# Encoded 1178/4305 sequences
# Encoded 1179/4305 sequences
# Encoded 1180/4305 sequences
# Encoded 1181/4305 sequences
# Encoded 1182/4305 sequences
# Encoded 1183/4305 sequences
# Encoded 1184/4305 sequences
# Encoded 1185/4305 sequences
# Encoded 1186/4305 sequences
# Encoded 1187/4305 sequences
# Encoded 1188/4305 sequences
# Encoded 1189/4305 sequences
# Encoded 1190/4305 sequences
# Encoded 1191/4305 sequences
# Encoded 1192/4305 sequences
# Encoded 1193/4305 sequences
# Encoded 1194/4305 sequences
# Encoded 1195/4305 sequences
# Encoded 1196/4305 sequences
# Encoded 1197/4305 sequences
# Encoded 1198/4305 sequences
# Encoded 1199/4305 sequences
# Encoded 1200/4305 sequences
# Encoded 1201/4305 sequences
# Encoded 1202/4305 sequences
# Encoded 1203/4305 sequences
# Encoded 1204/4305 sequences
# Encoded 1205/4305 sequences
# Encoded 1206/4305 sequences
# Encoded 1207/4305 sequences
# Encoded 1208/4305 sequences
# Encoded 1209/4305 sequences
# Encoded 1210/4305 sequences
# Encoded 1211/4305 sequences
# Encoded 1212/4305 sequences
# Encoded 1213/4305 sequences
# Encoded 1214/4305 sequences
# Encoded 1215/4305 sequences
# Encoded 1216/4305 sequences
# Encoded 1217/4305 sequences
# Encoded 1218/4305 sequences
# Encoded 1219/4305 sequences
# Encoded 1220/4305 sequences
# Encoded 1221/4305 sequences
# Encoded 1222/4305 sequences
# Encoded 1223/4305 sequences
# Encoded 1224/4305 sequences
# Encoded 1225/4305 sequences
# Encoded 1226/4305 sequences
# Encoded 1227/4305 sequences
# Encoded 1228/4305 sequences
# Encoded 1229/4305 sequences
# Encoded 1230/4305 sequences
# Encoded 1231/4305 sequences
# Encoded 1232/4305 sequences
# Encoded 1233/4305 sequences
# Encoded 1234/4305 sequences
# Encoded 1235/4305 sequences
# Encoded 1236/4305 sequences
# Encoded 1237/4305 sequences
# Encoded 1238/4305 sequences
# Encoded 1239/4305 sequences
# Encoded 1240/4305 sequences
# Encoded 1241/4305 sequences
# Encoded 1242/4305 sequences
# Encoded 1243/4305 sequences
# Encoded 1244/4305 sequences
# Encoded 1245/4305 sequences
# Encoded 1246/4305 sequences
# Encoded 1247/4305 sequences
# Encoded 1248/4305 sequences
# Encoded 1249/4305 sequences
# Encoded 1250/4305 sequences
# Encoded 1251/4305 sequences
# Encoded 1252/4305 sequences
# Encoded 1253/4305 sequences
# Encoded 1254/4305 sequences
# Encoded 1255/4305 sequences
# Encoded 1256/4305 sequences
# Encoded 1257/4305 sequences
# Encoded 1258/4305 sequences
# Encoded 1259/4305 sequences
# Encoded 1260/4305 sequences
# Encoded 1261/4305 sequences
# Encoded 1262/4305 sequences
# Encoded 1263/4305 sequences
# Encoded 1264/4305 sequences
# Encoded 1265/4305 sequences
# Encoded 1266/4305 sequences
# Encoded 1267/4305 sequences
# Encoded 1268/4305 sequences
# Encoded 1269/4305 sequences
# Encoded 1270/4305 sequences
# Encoded 1271/4305 sequences
# Encoded 1272/4305 sequences
# Encoded 1273/4305 sequences
# Encoded 1274/4305 sequences
# Encoded 1275/4305 sequences
# Encoded 1276/4305 sequences
# Encoded 1277/4305 sequences
# Encoded 1278/4305 sequences
# Encoded 1279/4305 sequences
# Encoded 1280/4305 sequences
# Encoded 1281/4305 sequences
# Encoded 1282/4305 sequences
# Encoded 1283/4305 sequences
# Encoded 1284/4305 sequences
# Encoded 1285/4305 sequences
# Encoded 1286/4305 sequences
# Encoded 1287/4305 sequences
# Encoded 1288/4305 sequences
# Encoded 1289/4305 sequences
# Encoded 1290/4305 sequences
# Encoded 1291/4305 sequences
# Encoded 1292/4305 sequences
# Encoded 1293/4305 sequences
# Encoded 1294/4305 sequences
# Encoded 1295/4305 sequences
# Encoded 1296/4305 sequences
# Encoded 1297/4305 sequences
# Encoded 1298/4305 sequences
# Encoded 1299/4305 sequences
# Encoded 1300/4305 sequences
# Encoded 1301/4305 sequences
# Encoded 1302/4305 sequences
# Encoded 1303/4305 sequences
# Encoded 1304/4305 sequences
# Encoded 1305/4305 sequences
# Encoded 1306/4305 sequences
# Encoded 1307/4305 sequences
# Encoded 1308/4305 sequences
# Encoded 1309/4305 sequences
# Encoded 1310/4305 sequences
# Encoded 1311/4305 sequences
# Encoded 1312/4305 sequences
# Encoded 1313/4305 sequences
# Encoded 1314/4305 sequences
# Encoded 1315/4305 sequences
# Encoded 1316/4305 sequences
# Encoded 1317/4305 sequences
# Encoded 1318/4305 sequences
# Encoded 1319/4305 sequences
# Encoded 1320/4305 sequences
# Encoded 1321/4305 sequences
# Encoded 1322/4305 sequences
# Encoded 1323/4305 sequences
# Encoded 1324/4305 sequences
# Encoded 1325/4305 sequences
# Encoded 1326/4305 sequences
# Encoded 1327/4305 sequences
# Encoded 1328/4305 sequences
# Encoded 1329/4305 sequences
# Encoded 1330/4305 sequences
# Encoded 1331/4305 sequences
# Encoded 1332/4305 sequences
# Encoded 1333/4305 sequences
# Encoded 1334/4305 sequences
# Encoded 1335/4305 sequences
# Encoded 1336/4305 sequences
# Encoded 1337/4305 sequences
# Encoded 1338/4305 sequences
# Encoded 1339/4305 sequences
# Encoded 1340/4305 sequences
# Encoded 1341/4305 sequences
# Encoded 1342/4305 sequences
# Encoded 1343/4305 sequences
# Encoded 1344/4305 sequences
# Encoded 1345/4305 sequences
# Encoded 1346/4305 sequences
# Encoded 1347/4305 sequences
# Encoded 1348/4305 sequences
# Encoded 1349/4305 sequences
# Encoded 1350/4305 sequences
# Encoded 1351/4305 sequences
# Encoded 1352/4305 sequences
# Encoded 1353/4305 sequences
# Encoded 1354/4305 sequences
# Encoded 1355/4305 sequences
# Encoded 1356/4305 sequences
# Encoded 1357/4305 sequences
# Encoded 1358/4305 sequences
# Encoded 1359/4305 sequences
# Encoded 1360/4305 sequences
# Encoded 1361/4305 sequences
# Encoded 1362/4305 sequences
# Encoded 1363/4305 sequences
# Encoded 1364/4305 sequences
# Encoded 1365/4305 sequences
# Encoded 1366/4305 sequences
# Encoded 1367/4305 sequences
# Encoded 1368/4305 sequences
# Encoded 1369/4305 sequences
# Encoded 1370/4305 sequences
# Encoded 1371/4305 sequences
# Encoded 1372/4305 sequences
# Encoded 1373/4305 sequences
# Encoded 1374/4305 sequences
# Encoded 1375/4305 sequences
# Encoded 1376/4305 sequences
# Encoded 1377/4305 sequences
# Encoded 1378/4305 sequences
# Encoded 1379/4305 sequences
# Encoded 1380/4305 sequences
# Encoded 1381/4305 sequences
# Encoded 1382/4305 sequences
# Encoded 1383/4305 sequences
# Encoded 1384/4305 sequences
# Encoded 1385/4305 sequences
# Encoded 1386/4305 sequences
# Encoded 1387/4305 sequences
# Encoded 1388/4305 sequences
# Encoded 1389/4305 sequences
# Encoded 1390/4305 sequences
# Encoded 1391/4305 sequences
# Encoded 1392/4305 sequences
# Encoded 1393/4305 sequences
# Encoded 1394/4305 sequences
# Encoded 1395/4305 sequences
# Encoded 1396/4305 sequences
# Encoded 1397/4305 sequences
# Encoded 1398/4305 sequences
# Encoded 1399/4305 sequences
# Encoded 1400/4305 sequences
# Encoded 1401/4305 sequences
# Encoded 1402/4305 sequences
# Encoded 1403/4305 sequences
# Encoded 1404/4305 sequences
# Encoded 1405/4305 sequences
# Encoded 1406/4305 sequences
# Encoded 1407/4305 sequences
# Encoded 1408/4305 sequences
# Encoded 1409/4305 sequences
# Encoded 1410/4305 sequences
# Encoded 1411/4305 sequences
# Encoded 1412/4305 sequences
# Encoded 1413/4305 sequences
# Encoded 1414/4305 sequences
# Encoded 1415/4305 sequences
# Encoded 1416/4305 sequences
# Encoded 1417/4305 sequences
# Encoded 1418/4305 sequences
# Encoded 1419/4305 sequences
# Encoded 1420/4305 sequences
# Encoded 1421/4305 sequences
# Encoded 1422/4305 sequences
# Encoded 1423/4305 sequences
# Encoded 1424/4305 sequences
# Encoded 1425/4305 sequences
# Encoded 1426/4305 sequences
# Encoded 1427/4305 sequences
# Encoded 1428/4305 sequences
# Encoded 1429/4305 sequences
# Encoded 1430/4305 sequences
# Encoded 1431/4305 sequences
# Encoded 1432/4305 sequences
# Encoded 1433/4305 sequences
# Encoded 1434/4305 sequences
# Encoded 1435/4305 sequences
# Encoded 1436/4305 sequences
# Encoded 1437/4305 sequences
# Encoded 1438/4305 sequences
# Encoded 1439/4305 sequences
# Encoded 1440/4305 sequences
# Encoded 1441/4305 sequences
# Encoded 1442/4305 sequences
# Encoded 1443/4305 sequences
# Encoded 1444/4305 sequences
# Encoded 1445/4305 sequences
# Encoded 1446/4305 sequences
# Encoded 1447/4305 sequences
# Encoded 1448/4305 sequences
# Encoded 1449/4305 sequences
# Encoded 1450/4305 sequences
# Encoded 1451/4305 sequences
# Encoded 1452/4305 sequences
# Encoded 1453/4305 sequences
# Encoded 1454/4305 sequences
# Encoded 1455/4305 sequences
# Encoded 1456/4305 sequences
# Encoded 1457/4305 sequences
# Encoded 1458/4305 sequences
# Encoded 1459/4305 sequences
# Encoded 1460/4305 sequences
# Encoded 1461/4305 sequences
# Encoded 1462/4305 sequences
# Encoded 1463/4305 sequences
# Encoded 1464/4305 sequences
# Encoded 1465/4305 sequences
# Encoded 1466/4305 sequences
# Encoded 1467/4305 sequences
# Encoded 1468/4305 sequences
# Encoded 1469/4305 sequences
# Encoded 1470/4305 sequences
# Encoded 1471/4305 sequences
# Encoded 1472/4305 sequences
# Encoded 1473/4305 sequences
# Encoded 1474/4305 sequences
# Encoded 1475/4305 sequences
# Encoded 1476/4305 sequences
# Encoded 1477/4305 sequences
# Encoded 1478/4305 sequences
# Encoded 1479/4305 sequences
# Encoded 1480/4305 sequences
# Encoded 1481/4305 sequences
# Encoded 1482/4305 sequences
# Encoded 1483/4305 sequences
# Encoded 1484/4305 sequences
# Encoded 1485/4305 sequences
# Encoded 1486/4305 sequences
# Encoded 1487/4305 sequences
# Encoded 1488/4305 sequences
# Encoded 1489/4305 sequences
# Encoded 1490/4305 sequences
# Encoded 1491/4305 sequences
# Encoded 1492/4305 sequences
# Encoded 1493/4305 sequences
# Encoded 1494/4305 sequences
# Encoded 1495/4305 sequences
# Encoded 1496/4305 sequences
# Encoded 1497/4305 sequences
# Encoded 1498/4305 sequences
# Encoded 1499/4305 sequences
# Encoded 1500/4305 sequences
# Encoded 1501/4305 sequences
# Encoded 1502/4305 sequences
# Encoded 1503/4305 sequences
# Encoded 1504/4305 sequences
# Encoded 1505/4305 sequences
# Encoded 1506/4305 sequences
# Encoded 1507/4305 sequences
# Encoded 1508/4305 sequences
# Encoded 1509/4305 sequences
# Encoded 1510/4305 sequences
# Encoded 1511/4305 sequences
# Encoded 1512/4305 sequences
# Encoded 1513/4305 sequences
# Encoded 1514/4305 sequences
# Encoded 1515/4305 sequences
# Encoded 1516/4305 sequences
# Encoded 1517/4305 sequences
# Encoded 1518/4305 sequences
# Encoded 1519/4305 sequences
# Encoded 1520/4305 sequences
# Encoded 1521/4305 sequences
# Encoded 1522/4305 sequences
# Encoded 1523/4305 sequences
# Encoded 1524/4305 sequences
# Encoded 1525/4305 sequences
# Encoded 1526/4305 sequences
# Encoded 1527/4305 sequences
# Encoded 1528/4305 sequences
# Encoded 1529/4305 sequences
# Encoded 1530/4305 sequences
# Encoded 1531/4305 sequences
# Encoded 1532/4305 sequences
# Encoded 1533/4305 sequences
# Encoded 1534/4305 sequences
# Encoded 1535/4305 sequences
# Encoded 1536/4305 sequences
# Encoded 1537/4305 sequences
# Encoded 1538/4305 sequences
# Encoded 1539/4305 sequences
# Encoded 1540/4305 sequences
# Encoded 1541/4305 sequences
# Encoded 1542/4305 sequences
# Encoded 1543/4305 sequences
# Encoded 1544/4305 sequences
# Encoded 1545/4305 sequences
# Encoded 1546/4305 sequences
# Encoded 1547/4305 sequences
# Encoded 1548/4305 sequences
# Encoded 1549/4305 sequences
# Encoded 1550/4305 sequences
# Encoded 1551/4305 sequences
# Encoded 1552/4305 sequences
# Encoded 1553/4305 sequences
# Encoded 1554/4305 sequences
# Encoded 1555/4305 sequences
# Encoded 1556/4305 sequences
# Encoded 1557/4305 sequences
# Encoded 1558/4305 sequences
# Encoded 1559/4305 sequences
# Encoded 1560/4305 sequences
# Encoded 1561/4305 sequences
# Encoded 1562/4305 sequences
# Encoded 1563/4305 sequences
# Encoded 1564/4305 sequences
# Encoded 1565/4305 sequences
# Encoded 1566/4305 sequences
# Encoded 1567/4305 sequences
# Encoded 1568/4305 sequences
# Encoded 1569/4305 sequences
# Encoded 1570/4305 sequences
# Encoded 1571/4305 sequences
# Encoded 1572/4305 sequences
# Encoded 1573/4305 sequences
# Encoded 1574/4305 sequences
# Encoded 1575/4305 sequences
# Encoded 1576/4305 sequences
# Encoded 1577/4305 sequences
# Encoded 1578/4305 sequences
# Encoded 1579/4305 sequences
# Encoded 1580/4305 sequences
# Encoded 1581/4305 sequences
# Encoded 1582/4305 sequences
# Encoded 1583/4305 sequences
# Encoded 1584/4305 sequences
# Encoded 1585/4305 sequences
# Encoded 1586/4305 sequences
# Encoded 1587/4305 sequences
# Encoded 1588/4305 sequences
# Encoded 1589/4305 sequences
# Encoded 1590/4305 sequences
# Encoded 1591/4305 sequences
# Encoded 1592/4305 sequences
# Encoded 1593/4305 sequences
# Encoded 1594/4305 sequences
# Encoded 1595/4305 sequences
# Encoded 1596/4305 sequences
# Encoded 1597/4305 sequences
# Encoded 1598/4305 sequences
# Encoded 1599/4305 sequences
# Encoded 1600/4305 sequences
# Encoded 1601/4305 sequences
# Encoded 1602/4305 sequences
# Encoded 1603/4305 sequences
# Encoded 1604/4305 sequences
# Encoded 1605/4305 sequences
# Encoded 1606/4305 sequences
# Encoded 1607/4305 sequences
# Encoded 1608/4305 sequences
# Encoded 1609/4305 sequences
# Encoded 1610/4305 sequences
# Encoded 1611/4305 sequences
# Encoded 1612/4305 sequences
# Encoded 1613/4305 sequences
# Encoded 1614/4305 sequences
# Encoded 1615/4305 sequences
# Encoded 1616/4305 sequences
# Encoded 1617/4305 sequences
# Encoded 1618/4305 sequences
# Encoded 1619/4305 sequences
# Encoded 1620/4305 sequences
# Encoded 1621/4305 sequences
# Encoded 1622/4305 sequences
# Encoded 1623/4305 sequences
# Encoded 1624/4305 sequences
# Encoded 1625/4305 sequences
# Encoded 1626/4305 sequences
# Encoded 1627/4305 sequences
# Encoded 1628/4305 sequences
# Encoded 1629/4305 sequences
# Encoded 1630/4305 sequences
# Encoded 1631/4305 sequences
# Encoded 1632/4305 sequences
# Encoded 1633/4305 sequences
# Encoded 1634/4305 sequences
# Encoded 1635/4305 sequences
# Encoded 1636/4305 sequences
# Encoded 1637/4305 sequences
# Encoded 1638/4305 sequences
# Encoded 1639/4305 sequences
# Encoded 1640/4305 sequences
# Encoded 1641/4305 sequences
# Encoded 1642/4305 sequences
# Encoded 1643/4305 sequences
# Encoded 1644/4305 sequences
# Encoded 1645/4305 sequences
# Encoded 1646/4305 sequences
# Encoded 1647/4305 sequences
# Encoded 1648/4305 sequences
# Encoded 1649/4305 sequences
# Encoded 1650/4305 sequences
# Encoded 1651/4305 sequences
# Encoded 1652/4305 sequences
# Encoded 1653/4305 sequences
# Encoded 1654/4305 sequences
# Encoded 1655/4305 sequences
# Encoded 1656/4305 sequences
# Encoded 1657/4305 sequences
# Encoded 1658/4305 sequences
# Encoded 1659/4305 sequences
# Encoded 1660/4305 sequences
# Encoded 1661/4305 sequences
# Encoded 1662/4305 sequences
# Encoded 1663/4305 sequences
# Encoded 1664/4305 sequences
# Encoded 1665/4305 sequences
# Encoded 1666/4305 sequences
# Encoded 1667/4305 sequences
# Encoded 1668/4305 sequences
# Encoded 1669/4305 sequences
# Encoded 1670/4305 sequences
# Encoded 1671/4305 sequences
# Encoded 1672/4305 sequences
# Encoded 1673/4305 sequences
# Encoded 1674/4305 sequences
# Encoded 1675/4305 sequences
# Encoded 1676/4305 sequences
# Encoded 1677/4305 sequences
# Encoded 1678/4305 sequences
# Encoded 1679/4305 sequences
# Encoded 1680/4305 sequences
# Encoded 1681/4305 sequences
# Encoded 1682/4305 sequences
# Encoded 1683/4305 sequences
# Encoded 1684/4305 sequences
# Encoded 1685/4305 sequences
# Encoded 1686/4305 sequences
# Encoded 1687/4305 sequences
# Encoded 1688/4305 sequences
# Encoded 1689/4305 sequences
# Encoded 1690/4305 sequences
# Encoded 1691/4305 sequences
# Encoded 1692/4305 sequences
# Encoded 1693/4305 sequences
# Encoded 1694/4305 sequences
# Encoded 1695/4305 sequences
# Encoded 1696/4305 sequences
# Encoded 1697/4305 sequences
# Encoded 1698/4305 sequences
# Encoded 1699/4305 sequences
# Encoded 1700/4305 sequences
# Encoded 1701/4305 sequences
# Encoded 1702/4305 sequences
# Encoded 1703/4305 sequences
# Encoded 1704/4305 sequences
# Encoded 1705/4305 sequences
# Encoded 1706/4305 sequences
# Encoded 1707/4305 sequences
# Encoded 1708/4305 sequences
# Encoded 1709/4305 sequences
# Encoded 1710/4305 sequences
# Encoded 1711/4305 sequences
# Encoded 1712/4305 sequences
# Encoded 1713/4305 sequences
# Encoded 1714/4305 sequences
# Encoded 1715/4305 sequences
# Encoded 1716/4305 sequences
# Encoded 1717/4305 sequences
# Encoded 1718/4305 sequences
# Encoded 1719/4305 sequences
# Encoded 1720/4305 sequences
# Encoded 1721/4305 sequences
# Encoded 1722/4305 sequences
# Encoded 1723/4305 sequences
# Encoded 1724/4305 sequences
# Encoded 1725/4305 sequences
# Encoded 1726/4305 sequences
# Encoded 1727/4305 sequences
# Encoded 1728/4305 sequences
# Encoded 1729/4305 sequences
# Encoded 1730/4305 sequences
# Encoded 1731/4305 sequences
# Encoded 1732/4305 sequences
# Encoded 1733/4305 sequences
# Encoded 1734/4305 sequences
# Encoded 1735/4305 sequences
# Encoded 1736/4305 sequences
# Encoded 1737/4305 sequences
# Encoded 1738/4305 sequences
# Encoded 1739/4305 sequences
# Encoded 1740/4305 sequences
# Encoded 1741/4305 sequences
# Encoded 1742/4305 sequences
# Encoded 1743/4305 sequences
# Encoded 1744/4305 sequences
# Encoded 1745/4305 sequences
# Encoded 1746/4305 sequences
# Encoded 1747/4305 sequences
# Encoded 1748/4305 sequences
# Encoded 1749/4305 sequences
# Encoded 1750/4305 sequences
# Encoded 1751/4305 sequences
# Encoded 1752/4305 sequences
# Encoded 1753/4305 sequences
# ...
# Encoded 4154/4305 sequences
# Encoded 4155/4305 sequences
# Encoded 4156/4305 sequences
# Encoded 4157/4305 sequences
# Encoded 4158/4305 sequences
# Encoded 4159/4305 sequences
# Encoded 4160/4305 sequences
# Encoded 4161/4305 sequences
# Encoded 4162/4305 sequences
# Encoded 4163/4305 sequences
# Encoded 4164/4305 sequences
# Encoded 4165/4305 sequences
# Encoded 4166/4305 sequences
# Encoded 4167/4305 sequences
# Encoded 4168/4305 sequences
# Encoded 4169/4305 sequences
# Encoded 4170/4305 sequences
# Encoded 4171/4305 sequences
# Encoded 4172/4305 sequences
# Encoded 4173/4305 sequences
# Encoded 4174/4305 sequences
# Encoded 4175/4305 sequences
# Encoded 4176/4305 sequences
# Encoded 4177/4305 sequences
# Encoded 4178/4305 sequences
# Encoded 4179/4305 sequences
# Encoded 4180/4305 sequences
# Encoded 4181/4305 sequences
# Encoded 4182/4305 sequences
# Encoded 4183/4305 sequences
# Encoded 4184/4305 sequences
# Encoded 4185/4305 sequences
# Encoded 4186/4305 sequences
# Encoded 4187/4305 sequences
# Encoded 4188/4305 sequences
# Encoded 4189/4305 sequences
# Encoded 4190/4305 sequences
# Encoded 4191/4305 sequences
# Encoded 4192/4305 sequences
# Encoded 4193/4305 sequences
# Encoded 4194/4305 sequences
# Encoded 4195/4305 sequences
# Encoded 4196/4305 sequences
# Encoded 4197/4305 sequences
# Encoded 4198/4305 sequences
# Encoded 4199/4305 sequences
# Encoded 4200/4305 sequences
# Encoded 4201/4305 sequences
# Encoded 4202/4305 sequences
# Encoded 4203/4305 sequences
# Encoded 4204/4305 sequences
# Encoded 4205/4305 sequences
# Encoded 4206/4305 sequences
# Encoded 4207/4305 sequences
# Encoded 4208/4305 sequences
# Encoded 4209/4305 sequences
# Encoded 4210/4305 sequences
# Encoded 4211/4305 sequences
# Encoded 4212/4305 sequences
# Encoded 4213/4305 sequences
# Encoded 4214/4305 sequences
# Encoded 4215/4305 sequences
# Encoded 4216/4305 sequences
# Encoded 4217/4305 sequences
# Encoded 4218/4305 sequences
# Encoded 4219/4305 sequences
# Encoded 4220/4305 sequences
# Encoded 4221/4305 sequences
# Encoded 4222/4305 sequences
# Encoded 4223/4305 sequences
# Encoded 4224/4305 sequences
# Encoded 4225/4305 sequences
# Encoded 4226/4305 sequences
# Encoded 4227/4305 sequences
# Encoded 4228/4305 sequences
# Encoded 4229/4305 sequences
# Encoded 4230/4305 sequences
# Encoded 4231/4305 sequences
# Encoded 4232/4305 sequences
# Encoded 4233/4305 sequences
# Encoded 4234/4305 sequences
# Encoded 4235/4305 sequences
# Encoded 4236/4305 sequences
# Encoded 4237/4305 sequences
# Encoded 4238/4305 sequences
# Encoded 4239/4305 sequences
# Encoded 4240/4305 sequences
# Encoded 4241/4305 sequences
# Encoded 4242/4305 sequences
# Encoded 4243/4305 sequences
# Encoded 4244/4305 sequences
# Encoded 4245/4305 sequences
# Encoded 4246/4305 sequences
# Encoded 4247/4305 sequences
# Encoded 4248/4305 sequences
# Encoded 4249/4305 sequences
# Encoded 4250/4305 sequences
# Encoded 4251/4305 sequences
# Encoded 4252/4305 sequences
# Encoded 4253/4305 sequences
# Encoded 4254/4305 sequences
# Encoded 4255/4305 sequences
# Encoded 4256/4305 sequences
# Encoded 4257/4305 sequences
# Encoded 4258/4305 sequences
# Encoded 4259/4305 sequences
# Encoded 4260/4305 sequences
# Encoded 4261/4305 sequences
# Encoded 4262/4305 sequences
# Encoded 4263/4305 sequences
# Encoded 4264/4305 sequences
# Encoded 4265/4305 sequences
# Encoded 4266/4305 sequences
# Encoded 4267/4305 sequences
# Encoded 4268/4305 sequences
# Encoded 4269/4305 sequences
# Encoded 4270/4305 sequences
# Encoded 4271/4305 sequences
# Encoded 4272/4305 sequences
# Encoded 4273/4305 sequences
# Encoded 4274/4305 sequences
# Encoded 4275/4305 sequences
# Encoded 4276/4305 sequences
# Encoded 4277/4305 sequences
# Encoded 4278/4305 sequences
# Encoded 4279/4305 sequences
# Encoded 4280/4305 sequences
# Encoded 4281/4305 sequences
# Encoded 4282/4305 sequences
# Encoded 4283/4305 sequences
# Encoded 4284/4305 sequences
# Encoded 4285/4305 sequences
# Encoded 4286/4305 sequences
# Encoded 4287/4305 sequences
# Encoded 4288/4305 sequences
# Encoded 4289/4305 sequences
# Encoded 4290/4305 sequences
# Encoded 4291/4305 sequences
# Encoded 4292/4305 sequences
# Encoded 4293/4305 sequences
# Encoded 4294/4305 sequences
# Encoded 4295/4305 sequences
# Encoded 4296/4305 sequences
# Encoded 4297/4305 sequences
# Encoded 4298/4305 sequences
# Encoded 4299/4305 sequences
# Encoded 4300/4305 sequences
# Encoded 4301/4305 sequences
# Encoded 4302/4305 sequences
# Encoded 4303/4305 sequences
# Encoded 4304/4305 sequences
# Encoded 4305/4305 sequences
# [[[ -3.5434945 ]
#   [ -3.36484792]
#   [ -2.52858527]
#   ...
#   [  0.        ]
#   [  0.        ]
#   [  0.        ]]
#
#  [[  4.05581453]
#   [  2.47482871]
#   [  3.35909195]
#   ...
#   [  0.        ]
#   [  0.        ]
#   [  0.        ]]
#
#  [[ 12.69329579]
#   [  9.54585652]
#   [  8.97902258]
#   ...
#   [  0.        ]
#   [  0.        ]
#   [  0.        ]]
#
#  ...
#
#  [[-11.24816614]
#   [-26.17834198]
#   [-35.41082097]
#   ...
#   [  0.        ]
#   [  0.        ]
#   [  0.        ]]
#
#  [[ -7.69057139]
#   [-23.11194323]
#   [-33.01679396]
#   ...
#   [  0.        ]
#   [  0.        ]
#   [  0.        ]]
#
#  [[  8.04237335]
#   [ -6.7799924 ]
#   [-15.53217741]
#   ...
#   [  0.        ]
#   [  0.        ]
#   [  0.        ]]]
# 2022-09-18 20:13:20.790294: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-18 20:13:21.836416: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7390 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2022-09-18 20:13:21.836965: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 7388 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/60
# 2022-09-18 20:13:26.155388: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8204
# 2022-09-18 20:13:26.405557: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-18 20:13:26.406262: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-18 20:13:26.406310: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-09-18 20:13:26.407147: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-18 20:13:26.407269: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 55/55 [==============================] - 7s 136ms/sample - loss: 0.0557 - mae: 0.1135 - val_loss: 0.0153 - val_mae: 0.0707 - lr: 0.0010
# Epoch 2/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 0.0130 - mae: 0.0593 - val_loss: 0.0117 - val_mae: 0.0604 - lr: 0.0010
# Epoch 3/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 0.0112 - mae: 0.0582 - val_loss: 0.0099 - val_mae: 0.0542 - lr: 0.0010
# Epoch 4/60
# 55/55 [==============================] - 2s 30ms/sample - loss: 0.0097 - mae: 0.0536 - val_loss: 0.0114 - val_mae: 0.0646 - lr: 0.0010
# Epoch 5/60
# 55/55 [==============================] - 2s 36ms/sample - loss: 0.0090 - mae: 0.0534 - val_loss: 0.0086 - val_mae: 0.0546 - lr: 0.0010
# Epoch 6/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 0.0079 - mae: 0.0481 - val_loss: 0.0072 - val_mae: 0.0435 - lr: 0.0010
# Epoch 7/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 0.0073 - mae: 0.0461 - val_loss: 0.0066 - val_mae: 0.0426 - lr: 0.0010
# Epoch 8/60
# 55/55 [==============================] - 2s 31ms/sample - loss: 0.0077 - mae: 0.0489 - val_loss: 0.0083 - val_mae: 0.0531 - lr: 0.0010
# Epoch 9/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 0.0072 - mae: 0.0478 - val_loss: 0.0062 - val_mae: 0.0434 - lr: 0.0010
# Epoch 10/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 0.0064 - mae: 0.0427 - val_loss: 0.0058 - val_mae: 0.0412 - lr: 0.0010
# Epoch 11/60
# 55/55 [==============================] - 2s 30ms/sample - loss: 0.0060 - mae: 0.0402 - val_loss: 0.0062 - val_mae: 0.0383 - lr: 0.0010
# Epoch 12/60
# 55/55 [==============================] - 2s 39ms/sample - loss: 0.0058 - mae: 0.0391 - val_loss: 0.0053 - val_mae: 0.0375 - lr: 0.0010
# Epoch 13/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 0.0055 - mae: 0.0383 - val_loss: 0.0051 - val_mae: 0.0387 - lr: 0.0010
# Epoch 14/60
# 55/55 [==============================] - 2s 30ms/sample - loss: 0.0056 - mae: 0.0409 - val_loss: 0.0079 - val_mae: 0.0582 - lr: 0.0010
# Epoch 15/60
# 55/55 [==============================] - 2s 36ms/sample - loss: 0.0054 - mae: 0.0402 - val_loss: 0.0046 - val_mae: 0.0381 - lr: 0.0010
# Epoch 16/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 0.0050 - mae: 0.0372 - val_loss: 0.0045 - val_mae: 0.0354 - lr: 0.0010
# Epoch 17/60
# 55/55 [==============================] - 3s 53ms/sample - loss: 0.0048 - mae: 0.0367 - val_loss: 0.0044 - val_mae: 0.0395 - lr: 0.0010
# Epoch 18/60
# 55/55 [==============================] - 2s 36ms/sample - loss: 0.0048 - mae: 0.0386 - val_loss: 0.0040 - val_mae: 0.0320 - lr: 0.0010
# Epoch 19/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 0.0041 - mae: 0.0337 - val_loss: 0.0040 - val_mae: 0.0320 - lr: 0.0010
# Epoch 20/60
# 55/55 [==============================] - 2s 30ms/sample - loss: 0.0040 - mae: 0.0338 - val_loss: 0.0052 - val_mae: 0.0431 - lr: 0.0010
# Epoch 21/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 0.0039 - mae: 0.0348 - val_loss: 0.0034 - val_mae: 0.0315 - lr: 0.0010
# Epoch 22/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 0.0035 - mae: 0.0321 - val_loss: 0.0029 - val_mae: 0.0288 - lr: 0.0010
# Epoch 23/60
# 55/55 [==============================] - 2s 31ms/sample - loss: 0.0032 - mae: 0.0315 - val_loss: 0.0032 - val_mae: 0.0331 - lr: 0.0010
# Epoch 24/60
# 55/55 [==============================] - 2s 36ms/sample - loss: 0.0033 - mae: 0.0326 - val_loss: 0.0026 - val_mae: 0.0280 - lr: 0.0010
# Epoch 25/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 0.0028 - mae: 0.0288 - val_loss: 0.0025 - val_mae: 0.0259 - lr: 0.0010
# Epoch 26/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 0.0027 - mae: 0.0288 - val_loss: 0.0024 - val_mae: 0.0293 - lr: 0.0010
# Epoch 27/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 0.0025 - mae: 0.0281 - val_loss: 0.0021 - val_mae: 0.0253 - lr: 0.0010
# Epoch 28/60
# 55/55 [==============================] - 3s 52ms/sample - loss: 0.0023 - mae: 0.0270 - val_loss: 0.0018 - val_mae: 0.0242 - lr: 0.0010
# Epoch 29/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 0.0021 - mae: 0.0262 - val_loss: 0.0018 - val_mae: 0.0240 - lr: 0.0010
# Epoch 30/60
# 55/55 [==============================] - 3s 47ms/sample - loss: 0.0018 - mae: 0.0240 - val_loss: 0.0017 - val_mae: 0.0221 - lr: 0.0010
# Epoch 31/60
# 55/55 [==============================] - 2s 31ms/sample - loss: 0.0017 - mae: 0.0232 - val_loss: 0.0017 - val_mae: 0.0242 - lr: 0.0010
# Epoch 32/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 0.0016 - mae: 0.0221 - val_loss: 0.0013 - val_mae: 0.0192 - lr: 0.0010
# Epoch 33/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 0.0014 - mae: 0.0204 - val_loss: 0.0013 - val_mae: 0.0211 - lr: 0.0010
# Epoch 34/60
# 55/55 [==============================] - 2s 31ms/sample - loss: 0.0013 - mae: 0.0203 - val_loss: 0.0014 - val_mae: 0.0229 - lr: 0.0010
# Epoch 35/60
# 55/55 [==============================] - 3s 50ms/sample - loss: 0.0014 - mae: 0.0217 - val_loss: 0.0013 - val_mae: 0.0207 - lr: 0.0010
# Epoch 36/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 0.0012 - mae: 0.0198 - val_loss: 0.0012 - val_mae: 0.0194 - lr: 0.0010
# Epoch 37/60
# 55/55 [==============================] - 2s 33ms/sample - loss: 0.0011 - mae: 0.0192 - val_loss: 9.8564e-04 - val_mae: 0.0184 - lr: 0.0010
# Epoch 38/60
# 55/55 [==============================] - 2s 36ms/sample - loss: 0.0011 - mae: 0.0191 - val_loss: 9.6395e-04 - val_mae: 0.0179 - lr: 0.0010
# Epoch 39/60
# 55/55 [==============================] - 2s 31ms/sample - loss: 0.0011 - mae: 0.0184 - val_loss: 0.0010 - val_mae: 0.0181 - lr: 0.0010
# Epoch 40/60
# 55/55 [==============================] - 2s 44ms/sample - loss: 9.7390e-04 - mae: 0.0175 - val_loss: 9.6345e-04 - val_mae: 0.0180 - lr: 0.0010
# Epoch 41/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 9.4512e-04 - mae: 0.0178 - val_loss: 8.5031e-04 - val_mae: 0.0162 - lr: 0.0010
# Epoch 42/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 8.9320e-04 - mae: 0.0170 - val_loss: 8.0311e-04 - val_mae: 0.0169 - lr: 0.0010
# Epoch 43/60
# 55/55 [==============================] - 2s 31ms/sample - loss: 8.3338e-04 - mae: 0.0167 - val_loss: 8.6938e-04 - val_mae: 0.0173 - lr: 0.0010
# Epoch 44/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 8.4884e-04 - mae: 0.0172 - val_loss: 6.9809e-04 - val_mae: 0.0152 - lr: 0.0010
# Epoch 45/60
# 55/55 [==============================] - 2s 31ms/sample - loss: 8.8070e-04 - mae: 0.0176 - val_loss: 9.0633e-04 - val_mae: 0.0183 - lr: 0.0010
# Epoch 46/60
# 55/55 [==============================] - 3s 53ms/sample - loss: 8.2839e-04 - mae: 0.0166 - val_loss: 6.7531e-04 - val_mae: 0.0145 - lr: 0.0010
# Epoch 47/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 7.0865e-04 - mae: 0.0153 - val_loss: 6.0290e-04 - val_mae: 0.0143 - lr: 0.0010
# Epoch 48/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 6.1118e-04 - mae: 0.0141 - val_loss: 5.3590e-04 - val_mae: 0.0132 - lr: 0.0010
# Epoch 49/60
# 55/55 [==============================] - 2s 31ms/sample - loss: 6.2749e-04 - mae: 0.0149 - val_loss: 5.6344e-04 - val_mae: 0.0135 - lr: 0.0010
# Epoch 50/60
# 55/55 [==============================] - 2s 31ms/sample - loss: 5.7609e-04 - mae: 0.0140 - val_loss: 5.6286e-04 - val_mae: 0.0150 - lr: 0.0010
# Epoch 51/60
# 55/55 [==============================] - 3s 50ms/sample - loss: 5.8451e-04 - mae: 0.0143 - val_loss: 5.0409e-04 - val_mae: 0.0126 - lr: 0.0010
# Epoch 52/60
# 55/55 [==============================] - 2s 30ms/sample - loss: 5.7555e-04 - mae: 0.0143 - val_loss: 6.0885e-04 - val_mae: 0.0147 - lr: 0.0010
# Epoch 53/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 5.7263e-04 - mae: 0.0142 - val_loss: 5.0279e-04 - val_mae: 0.0130 - lr: 0.0010
# Epoch 54/60
# 55/55 [==============================] - 2s 31ms/sample - loss: 6.2704e-04 - mae: 0.0155 - val_loss: 0.0012 - val_mae: 0.0221 - lr: 0.0010
# Epoch 55/60
#  0/55 [..............................] - ETA: 0s - loss: 7.4501e-04 - mae: 0.0168
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 55/55 [==============================] - 2s 31ms/sample - loss: 7.4501e-04 - mae: 0.0168 - val_loss: 6.1660e-04 - val_mae: 0.0141 - lr: 0.0010
# Epoch 56/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 4.8641e-04 - mae: 0.0125 - val_loss: 3.9903e-04 - val_mae: 0.0114 - lr: 1.0000e-04
# Epoch 57/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 3.8668e-04 - mae: 0.0112 - val_loss: 3.5142e-04 - val_mae: 0.0106 - lr: 1.0000e-04
# Epoch 58/60
# 55/55 [==============================] - 2s 35ms/sample - loss: 3.4919e-04 - mae: 0.0107 - val_loss: 3.3056e-04 - val_mae: 0.0104 - lr: 1.0000e-04
# Epoch 59/60
# 55/55 [==============================] - 2s 33ms/sample - loss: 3.2771e-04 - mae: 0.0104 - val_loss: 3.0963e-04 - val_mae: 0.0101 - lr: 1.0000e-04
# Epoch 60/60
# 55/55 [==============================] - 2s 34ms/sample - loss: 3.0981e-04 - mae: 0.0101 - val_loss: 2.9625e-04 - val_mae: 0.0098 - lr: 1.0000e-04

# %%
plt.plot(trained.history.history['mae'])
plt.plot(trained.history.history['val_mae'])
plt.title('model absolute error')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(trained.history.history['loss'])
plt.plot(trained.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Validation set results

# %%
val = data.loc[val_ids]
seqs = list(val.train_seq)
tr=[]
for n,r in val.iterrows():
    tr.append(np.mean((r['rot'][0::2] + r['rot'][1::2]) / 2)/2)
res = mod.predict(seqs)
pr = []
for n,r in res.iterrows():
    pr.append(np.mean(r['N_pred'])/2)
# Out:
# /tmp/ipykernel_6474/79076738.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   val = data.loc[val_ids]
# Encoded 1/448 sequences
# Encoded 2/448 sequences
# Encoded 3/448 sequences
# Encoded 4/448 sequences
# Encoded 5/448 sequences
# Encoded 6/448 sequences
# Encoded 7/448 sequences
# Encoded 8/448 sequences
# Encoded 9/448 sequences
# Encoded 10/448 sequences
# Encoded 11/448 sequences
# Encoded 12/448 sequences
# Encoded 13/448 sequences
# Encoded 14/448 sequences
# Encoded 15/448 sequences
# Encoded 16/448 sequences
# Encoded 17/448 sequences
# Encoded 18/448 sequences
# Encoded 19/448 sequences
# Encoded 20/448 sequences
# Encoded 21/448 sequences
# Encoded 22/448 sequences
# Encoded 23/448 sequences
# Encoded 24/448 sequences
# Encoded 25/448 sequences
# Encoded 26/448 sequences
# Encoded 27/448 sequences
# Encoded 28/448 sequences
# Encoded 29/448 sequences
# Encoded 30/448 sequences
# Encoded 31/448 sequences
# Encoded 32/448 sequences
# Encoded 33/448 sequences
# Encoded 34/448 sequences
# Encoded 35/448 sequences
# Encoded 36/448 sequences
# Encoded 37/448 sequences
# Encoded 38/448 sequences
# Encoded 39/448 sequences
# Encoded 40/448 sequences
# Encoded 41/448 sequences
# Encoded 42/448 sequences
# Encoded 43/448 sequences
# Encoded 44/448 sequences
# Encoded 45/448 sequences
# Encoded 46/448 sequences
# Encoded 47/448 sequences
# Encoded 48/448 sequences
# Encoded 49/448 sequences
# Encoded 50/448 sequences
# Encoded 51/448 sequences
# Encoded 52/448 sequences
# Encoded 53/448 sequences
# Encoded 54/448 sequences
# Encoded 55/448 sequences
# Encoded 56/448 sequences
# Encoded 57/448 sequences
# Encoded 58/448 sequences
# Encoded 59/448 sequences
# Encoded 60/448 sequences
# Encoded 61/448 sequences
# Encoded 62/448 sequences
# Encoded 63/448 sequences
# Encoded 64/448 sequences
# Encoded 65/448 sequences
# Encoded 66/448 sequences
# Encoded 67/448 sequences
# Encoded 68/448 sequences
# Encoded 69/448 sequences
# Encoded 70/448 sequences
# Encoded 71/448 sequences
# Encoded 72/448 sequences
# Encoded 73/448 sequences
# Encoded 74/448 sequences
# Encoded 75/448 sequences
# Encoded 76/448 sequences
# Encoded 77/448 sequences
# Encoded 78/448 sequences
# Encoded 79/448 sequences
# Encoded 80/448 sequences
# Encoded 81/448 sequences
# Encoded 82/448 sequences
# Encoded 83/448 sequences
# Encoded 84/448 sequences
# Encoded 85/448 sequences
# Encoded 86/448 sequences
# Encoded 87/448 sequences
# Encoded 88/448 sequences
# Encoded 89/448 sequences
# Encoded 90/448 sequences
# Encoded 91/448 sequences
# Encoded 92/448 sequences
# Encoded 93/448 sequences
# Encoded 94/448 sequences
# Encoded 95/448 sequences
# Encoded 96/448 sequences
# Encoded 97/448 sequences
# Encoded 98/448 sequences
# Encoded 99/448 sequences
# Encoded 100/448 sequences
# Encoded 101/448 sequences
# Encoded 102/448 sequences
# Encoded 103/448 sequences
# Encoded 104/448 sequences
# Encoded 105/448 sequences
# Encoded 106/448 sequences
# Encoded 107/448 sequences
# Encoded 108/448 sequences
# Encoded 109/448 sequences
# Encoded 110/448 sequences
# Encoded 111/448 sequences
# Encoded 112/448 sequences
# Encoded 113/448 sequences
# Encoded 114/448 sequences
# Encoded 115/448 sequences
# Encoded 116/448 sequences
# Encoded 117/448 sequences
# Encoded 118/448 sequences
# Encoded 119/448 sequences
# Encoded 120/448 sequences
# Encoded 121/448 sequences
# Encoded 122/448 sequences
# Encoded 123/448 sequences
# Encoded 124/448 sequences
# Encoded 125/448 sequences
# Encoded 126/448 sequences
# Encoded 127/448 sequences
# Encoded 128/448 sequences
# Encoded 129/448 sequences
# Encoded 130/448 sequences
# Encoded 131/448 sequences
# Encoded 132/448 sequences
# Encoded 133/448 sequences
# Encoded 134/448 sequences
# Encoded 135/448 sequences
# Encoded 136/448 sequences
# Encoded 137/448 sequences
# Encoded 138/448 sequences
# Encoded 139/448 sequences
# Encoded 140/448 sequences
# Encoded 141/448 sequences
# Encoded 142/448 sequences
# Encoded 143/448 sequences
# Encoded 144/448 sequences
# Encoded 145/448 sequences
# Encoded 146/448 sequences
# Encoded 147/448 sequences
# Encoded 148/448 sequences
# Encoded 149/448 sequences
# Encoded 150/448 sequences
# Encoded 151/448 sequences
# Encoded 152/448 sequences
# Encoded 153/448 sequences
# Encoded 154/448 sequences
# Encoded 155/448 sequences
# Encoded 156/448 sequences
# Encoded 157/448 sequences
# Encoded 158/448 sequences
# Encoded 159/448 sequences
# Encoded 160/448 sequences
# Encoded 161/448 sequences
# Encoded 162/448 sequences
# Encoded 163/448 sequences
# Encoded 164/448 sequences
# Encoded 165/448 sequences
# Encoded 166/448 sequences
# Encoded 167/448 sequences
# Encoded 168/448 sequences
# Encoded 169/448 sequences
# Encoded 170/448 sequences
# Encoded 171/448 sequences
# Encoded 172/448 sequences
# Encoded 173/448 sequences
# Encoded 174/448 sequences
# Encoded 175/448 sequences
# Encoded 176/448 sequences
# Encoded 177/448 sequences
# Encoded 178/448 sequences
# Encoded 179/448 sequences
# Encoded 180/448 sequences
# Encoded 181/448 sequences
# Encoded 182/448 sequences
# Encoded 183/448 sequences
# Encoded 184/448 sequences
# Encoded 185/448 sequences
# Encoded 186/448 sequences
# Encoded 187/448 sequences
# Encoded 188/448 sequences
# Encoded 189/448 sequences
# Encoded 190/448 sequences
# Encoded 191/448 sequences
# Encoded 192/448 sequences
# Encoded 193/448 sequences
# Encoded 194/448 sequences
# Encoded 195/448 sequences
# Encoded 196/448 sequences
# Encoded 197/448 sequences
# Encoded 198/448 sequences
# Encoded 199/448 sequences
# Encoded 200/448 sequences
# Encoded 201/448 sequences
# Encoded 202/448 sequences
# Encoded 203/448 sequences
# Encoded 204/448 sequences
# Encoded 205/448 sequences
# Encoded 206/448 sequences
# Encoded 207/448 sequences
# Encoded 208/448 sequences
# Encoded 209/448 sequences
# Encoded 210/448 sequences
# Encoded 211/448 sequences
# Encoded 212/448 sequences
# Encoded 213/448 sequences
# Encoded 214/448 sequences
# Encoded 215/448 sequences
# Encoded 216/448 sequences
# Encoded 217/448 sequences
# Encoded 218/448 sequences
# Encoded 219/448 sequences
# Encoded 220/448 sequences
# Encoded 221/448 sequences
# Encoded 222/448 sequences
# Encoded 223/448 sequences
# Encoded 224/448 sequences
# Encoded 225/448 sequences
# Encoded 226/448 sequences
# Encoded 227/448 sequences
# Encoded 228/448 sequences
# Encoded 229/448 sequences
# Encoded 230/448 sequences
# Encoded 231/448 sequences
# Encoded 232/448 sequences
# Encoded 233/448 sequences
# Encoded 234/448 sequences
# Encoded 235/448 sequences
# Encoded 236/448 sequences
# Encoded 237/448 sequences
# Encoded 238/448 sequences
# Encoded 239/448 sequences
# Encoded 240/448 sequences
# Encoded 241/448 sequences
# Encoded 242/448 sequences
# Encoded 243/448 sequences
# Encoded 244/448 sequences
# Encoded 245/448 sequences
# Encoded 246/448 sequences
# Encoded 247/448 sequences
# Encoded 248/448 sequences
# Encoded 249/448 sequences
# Encoded 250/448 sequences
# Encoded 251/448 sequences
# Encoded 252/448 sequences
# Encoded 253/448 sequences
# Encoded 254/448 sequences
# Encoded 255/448 sequences
# Encoded 256/448 sequences
# Encoded 257/448 sequences
# Encoded 258/448 sequences
# Encoded 259/448 sequences
# Encoded 260/448 sequences
# Encoded 261/448 sequences
# Encoded 262/448 sequences
# Encoded 263/448 sequences
# Encoded 264/448 sequences
# Encoded 265/448 sequences
# Encoded 266/448 sequences
# Encoded 267/448 sequences
# Encoded 268/448 sequences
# Encoded 269/448 sequences
# Encoded 270/448 sequences
# Encoded 271/448 sequences
# Encoded 272/448 sequences
# Encoded 273/448 sequences
# Encoded 274/448 sequences
# Encoded 275/448 sequences
# Encoded 276/448 sequences
# Encoded 277/448 sequences
# Encoded 278/448 sequences
# Encoded 279/448 sequences
# Encoded 280/448 sequences
# Encoded 281/448 sequences
# Encoded 282/448 sequences
# Encoded 283/448 sequences
# Encoded 284/448 sequences
# Encoded 285/448 sequences
# Encoded 286/448 sequences
# Encoded 287/448 sequences
# Encoded 288/448 sequences
# Encoded 289/448 sequences
# Encoded 290/448 sequences
# Encoded 291/448 sequences
# Encoded 292/448 sequences
# Encoded 293/448 sequences
# Encoded 294/448 sequences
# Encoded 295/448 sequences
# Encoded 296/448 sequences
# Encoded 297/448 sequences
# Encoded 298/448 sequences
# Encoded 299/448 sequences
# Encoded 300/448 sequences
# Encoded 301/448 sequences
# Encoded 302/448 sequences
# Encoded 303/448 sequences
# Encoded 304/448 sequences
# Encoded 305/448 sequences
# Encoded 306/448 sequences
# Encoded 307/448 sequences
# Encoded 308/448 sequences
# Encoded 309/448 sequences
# Encoded 310/448 sequences
# Encoded 311/448 sequences
# Encoded 312/448 sequences
# Encoded 313/448 sequences
# Encoded 314/448 sequences
# Encoded 315/448 sequences
# Encoded 316/448 sequences
# Encoded 317/448 sequences
# Encoded 318/448 sequences
# Encoded 319/448 sequences
# Encoded 320/448 sequences
# Encoded 321/448 sequences
# Encoded 322/448 sequences
# Encoded 323/448 sequences
# Encoded 324/448 sequences
# Encoded 325/448 sequences
# Encoded 326/448 sequences
# Encoded 327/448 sequences
# Encoded 328/448 sequences
# Encoded 329/448 sequences
# Encoded 330/448 sequences
# Encoded 331/448 sequences
# Encoded 332/448 sequences
# Encoded 333/448 sequences
# Encoded 334/448 sequences
# Encoded 335/448 sequences
# Encoded 336/448 sequences
# Encoded 337/448 sequences
# Encoded 338/448 sequences
# Encoded 339/448 sequences
# Encoded 340/448 sequences
# Encoded 341/448 sequences
# Encoded 342/448 sequences
# Encoded 343/448 sequences
# Encoded 344/448 sequences
# Encoded 345/448 sequences
# Encoded 346/448 sequences
# Encoded 347/448 sequences
# Encoded 348/448 sequences
# Encoded 349/448 sequences
# Encoded 350/448 sequences
# Encoded 351/448 sequences
# Encoded 352/448 sequences
# Encoded 353/448 sequences
# Encoded 354/448 sequences
# Encoded 355/448 sequences
# Encoded 356/448 sequences
# Encoded 357/448 sequences
# Encoded 358/448 sequences
# Encoded 359/448 sequences
# Encoded 360/448 sequences
# Encoded 361/448 sequences
# Encoded 362/448 sequences
# Encoded 363/448 sequences
# Encoded 364/448 sequences
# Encoded 365/448 sequences
# Encoded 366/448 sequences
# Encoded 367/448 sequences
# Encoded 368/448 sequences
# Encoded 369/448 sequences
# Encoded 370/448 sequences
# Encoded 371/448 sequences
# Encoded 372/448 sequences
# Encoded 373/448 sequences
# Encoded 374/448 sequences
# Encoded 375/448 sequences
# Encoded 376/448 sequences
# Encoded 377/448 sequences
# Encoded 378/448 sequences
# Encoded 379/448 sequences
# Encoded 380/448 sequences
# Encoded 381/448 sequences
# Encoded 382/448 sequences
# Encoded 383/448 sequences
# Encoded 384/448 sequences
# Encoded 385/448 sequences
# Encoded 386/448 sequences
# Encoded 387/448 sequences
# Encoded 388/448 sequences
# Encoded 389/448 sequences
# Encoded 390/448 sequences
# Encoded 391/448 sequences
# Encoded 392/448 sequences
# Encoded 393/448 sequences
# Encoded 394/448 sequences
# Encoded 395/448 sequences
# Encoded 396/448 sequences
# Encoded 397/448 sequences
# Encoded 398/448 sequences
# Encoded 399/448 sequences
# Encoded 400/448 sequences
# Encoded 401/448 sequences
# Encoded 402/448 sequences
# Encoded 403/448 sequences
# Encoded 404/448 sequences
# Encoded 405/448 sequences
# Encoded 406/448 sequences
# Encoded 407/448 sequences
# Encoded 408/448 sequences
# Encoded 409/448 sequences
# Encoded 410/448 sequences
# Encoded 411/448 sequences
# Encoded 412/448 sequences
# Encoded 413/448 sequences
# Encoded 414/448 sequences
# Encoded 415/448 sequences
# Encoded 416/448 sequences
# Encoded 417/448 sequences
# Encoded 418/448 sequences
# Encoded 419/448 sequences
# Encoded 420/448 sequences
# Encoded 421/448 sequences
# Encoded 422/448 sequences
# Encoded 423/448 sequences
# Encoded 424/448 sequences
# Encoded 425/448 sequences
# Encoded 426/448 sequences
# Encoded 427/448 sequences
# Encoded 428/448 sequences
# Encoded 429/448 sequences
# Encoded 430/448 sequences
# Encoded 431/448 sequences
# Encoded 432/448 sequences
# Encoded 433/448 sequences
# Encoded 434/448 sequences
# Encoded 435/448 sequences
# Encoded 436/448 sequences
# Encoded 437/448 sequences
# Encoded 438/448 sequences
# Encoded 439/448 sequences
# Encoded 440/448 sequences
# Encoded 441/448 sequences
# Encoded 442/448 sequences
# Encoded 443/448 sequences
# Encoded 444/448 sequences
# Encoded 445/448 sequences
# Encoded 446/448 sequences
# Encoded 447/448 sequences
# Encoded 448/448 sequences
# Encoded 1/448 sequences
# Encoded 2/448 sequences
# Encoded 3/448 sequences
# Encoded 4/448 sequences
# Encoded 5/448 sequences
# Encoded 6/448 sequences
# Encoded 7/448 sequences
# Encoded 8/448 sequences
# Encoded 9/448 sequences
# Encoded 10/448 sequences
# Encoded 11/448 sequences
# Encoded 12/448 sequences
# Encoded 13/448 sequences
# Encoded 14/448 sequences
# Encoded 15/448 sequences
# Encoded 16/448 sequences
# Encoded 17/448 sequences
# Encoded 18/448 sequences
# Encoded 19/448 sequences
# Encoded 20/448 sequences
# Encoded 21/448 sequences
# Encoded 22/448 sequences
# Encoded 23/448 sequences
# Encoded 24/448 sequences
# Encoded 25/448 sequences
# Encoded 26/448 sequences
# Encoded 27/448 sequences
# Encoded 28/448 sequences
# Encoded 29/448 sequences
# Encoded 30/448 sequences
# Encoded 31/448 sequences
# Encoded 32/448 sequences
# Encoded 33/448 sequences
# Encoded 34/448 sequences
# Encoded 35/448 sequences
# Encoded 36/448 sequences
# Encoded 37/448 sequences
# Encoded 38/448 sequences
# Encoded 39/448 sequences
# Encoded 40/448 sequences
# Encoded 41/448 sequences
# Encoded 42/448 sequences
# Encoded 43/448 sequences
# Encoded 44/448 sequences
# Encoded 45/448 sequences
# Encoded 46/448 sequences
# Encoded 47/448 sequences
# Encoded 48/448 sequences
# Encoded 49/448 sequences
# Encoded 50/448 sequences
# Encoded 51/448 sequences
# Encoded 52/448 sequences
# Encoded 53/448 sequences
# Encoded 54/448 sequences
# Encoded 55/448 sequences
# Encoded 56/448 sequences
# Encoded 57/448 sequences
# Encoded 58/448 sequences
# Encoded 59/448 sequences
# Encoded 60/448 sequences
# Encoded 61/448 sequences
# Encoded 62/448 sequences
# Encoded 63/448 sequences
# Encoded 64/448 sequences
# Encoded 65/448 sequences
# Encoded 66/448 sequences
# Encoded 67/448 sequences
# Encoded 68/448 sequences
# Encoded 69/448 sequences
# Encoded 70/448 sequences
# Encoded 71/448 sequences
# Encoded 72/448 sequences
# Encoded 73/448 sequences
# Encoded 74/448 sequences
# Encoded 75/448 sequences
# Encoded 76/448 sequences
# Encoded 77/448 sequences
# Encoded 78/448 sequences
# Encoded 79/448 sequences
# Encoded 80/448 sequences
# Encoded 81/448 sequences
# Encoded 82/448 sequences
# Encoded 83/448 sequences
# Encoded 84/448 sequences
# Encoded 85/448 sequences
# Encoded 86/448 sequences
# Encoded 87/448 sequences
# Encoded 88/448 sequences
# Encoded 89/448 sequences
# Encoded 90/448 sequences
# Encoded 91/448 sequences
# Encoded 92/448 sequences
# Encoded 93/448 sequences
# Encoded 94/448 sequences
# Encoded 95/448 sequences
# Encoded 96/448 sequences
# Encoded 97/448 sequences
# Encoded 98/448 sequences
# Encoded 99/448 sequences
# Encoded 100/448 sequences
# Encoded 101/448 sequences
# Encoded 102/448 sequences
# Encoded 103/448 sequences
# Encoded 104/448 sequences
# Encoded 105/448 sequences
# Encoded 106/448 sequences
# Encoded 107/448 sequences
# Encoded 108/448 sequences
# Encoded 109/448 sequences
# Encoded 110/448 sequences
# Encoded 111/448 sequences
# Encoded 112/448 sequences
# Encoded 113/448 sequences
# Encoded 114/448 sequences
# Encoded 115/448 sequences
# Encoded 116/448 sequences
# Encoded 117/448 sequences
# Encoded 118/448 sequences
# Encoded 119/448 sequences
# Encoded 120/448 sequences
# Encoded 121/448 sequences
# Encoded 122/448 sequences
# Encoded 123/448 sequences
# Encoded 124/448 sequences
# Encoded 125/448 sequences
# Encoded 126/448 sequences
# Encoded 127/448 sequences
# Encoded 128/448 sequences
# Encoded 129/448 sequences
# Encoded 130/448 sequences
# Encoded 131/448 sequences
# Encoded 132/448 sequences
# Encoded 133/448 sequences
# Encoded 134/448 sequences
# Encoded 135/448 sequences
# Encoded 136/448 sequences
# Encoded 137/448 sequences
# Encoded 138/448 sequences
# Encoded 139/448 sequences
# Encoded 140/448 sequences
# Encoded 141/448 sequences
# Encoded 142/448 sequences
# Encoded 143/448 sequences
# Encoded 144/448 sequences
# Encoded 145/448 sequences
# Encoded 146/448 sequences
# Encoded 147/448 sequences
# Encoded 148/448 sequences
# Encoded 149/448 sequences
# Encoded 150/448 sequences
# Encoded 151/448 sequences
# Encoded 152/448 sequences
# Encoded 153/448 sequences
# Encoded 154/448 sequences
# Encoded 155/448 sequences
# Encoded 156/448 sequences
# Encoded 157/448 sequences
# Encoded 158/448 sequences
# Encoded 159/448 sequences
# Encoded 160/448 sequences
# Encoded 161/448 sequences
# Encoded 162/448 sequences
# Encoded 163/448 sequences
# Encoded 164/448 sequences
# Encoded 165/448 sequences
# Encoded 166/448 sequences
# Encoded 167/448 sequences
# Encoded 168/448 sequences
# Encoded 169/448 sequences
# Encoded 170/448 sequences
# Encoded 171/448 sequences
# Encoded 172/448 sequences
# Encoded 173/448 sequences
# Encoded 174/448 sequences
# Encoded 175/448 sequences
# Encoded 176/448 sequences
# Encoded 177/448 sequences
# Encoded 178/448 sequences
# Encoded 179/448 sequences
# Encoded 180/448 sequences
# Encoded 181/448 sequences
# Encoded 182/448 sequences
# Encoded 183/448 sequences
# Encoded 184/448 sequences
# Encoded 185/448 sequences
# Encoded 186/448 sequences
# Encoded 187/448 sequences
# Encoded 188/448 sequences
# Encoded 189/448 sequences
# Encoded 190/448 sequences
# Encoded 191/448 sequences
# Encoded 192/448 sequences
# Encoded 193/448 sequences
# Encoded 194/448 sequences
# Encoded 195/448 sequences
# Encoded 196/448 sequences
# Encoded 197/448 sequences
# Encoded 198/448 sequences
# Encoded 199/448 sequences
# Encoded 200/448 sequences
# Encoded 201/448 sequences
# Encoded 202/448 sequences
# Encoded 203/448 sequences
# Encoded 204/448 sequences
# Encoded 205/448 sequences
# Encoded 206/448 sequences
# Encoded 207/448 sequences
# Encoded 208/448 sequences
# Encoded 209/448 sequences
# Encoded 210/448 sequences
# Encoded 211/448 sequences
# Encoded 212/448 sequences
# Encoded 213/448 sequences
# Encoded 214/448 sequences
# Encoded 215/448 sequences
# Encoded 216/448 sequences
# Encoded 217/448 sequences
# Encoded 218/448 sequences
# Encoded 219/448 sequences
# Encoded 220/448 sequences
# Encoded 221/448 sequences
# Encoded 222/448 sequences
# Encoded 223/448 sequences
# Encoded 224/448 sequences
# Encoded 225/448 sequences
# Encoded 226/448 sequences
# Encoded 227/448 sequences
# Encoded 228/448 sequences
# Encoded 229/448 sequences
# Encoded 230/448 sequences
# Encoded 231/448 sequences
# Encoded 232/448 sequences
# Encoded 233/448 sequences
# Encoded 234/448 sequences
# Encoded 235/448 sequences
# Encoded 236/448 sequences
# Encoded 237/448 sequences
# Encoded 238/448 sequences
# Encoded 239/448 sequences
# Encoded 240/448 sequences
# Encoded 241/448 sequences
# Encoded 242/448 sequences
# Encoded 243/448 sequences
# Encoded 244/448 sequences
# Encoded 245/448 sequences
# Encoded 246/448 sequences
# Encoded 247/448 sequences
# Encoded 248/448 sequences
# Encoded 249/448 sequences
# Encoded 250/448 sequences
# Encoded 251/448 sequences
# Encoded 252/448 sequences
# Encoded 253/448 sequences
# Encoded 254/448 sequences
# Encoded 255/448 sequences
# Encoded 256/448 sequences
# Encoded 257/448 sequences
# Encoded 258/448 sequences
# Encoded 259/448 sequences
# Encoded 260/448 sequences
# Encoded 261/448 sequences
# Encoded 262/448 sequences
# Encoded 263/448 sequences
# Encoded 264/448 sequences
# Encoded 265/448 sequences
# Encoded 266/448 sequences
# Encoded 267/448 sequences
# Encoded 268/448 sequences
# Encoded 269/448 sequences
# Encoded 270/448 sequences
# Encoded 271/448 sequences
# Encoded 272/448 sequences
# Encoded 273/448 sequences
# Encoded 274/448 sequences
# Encoded 275/448 sequences
# Encoded 276/448 sequences
# Encoded 277/448 sequences
# Encoded 278/448 sequences
# Encoded 279/448 sequences
# Encoded 280/448 sequences
# Encoded 281/448 sequences
# Encoded 282/448 sequences
# Encoded 283/448 sequences
# Encoded 284/448 sequences
# Encoded 285/448 sequences
# Encoded 286/448 sequences
# Encoded 287/448 sequences
# Encoded 288/448 sequences
# Encoded 289/448 sequences
# Encoded 290/448 sequences
# Encoded 291/448 sequences
# Encoded 292/448 sequences
# Encoded 293/448 sequences
# Encoded 294/448 sequences
# Encoded 295/448 sequences
# Encoded 296/448 sequences
# Encoded 297/448 sequences
# Encoded 298/448 sequences
# Encoded 299/448 sequences
# Encoded 300/448 sequences
# Encoded 301/448 sequences
# Encoded 302/448 sequences
# Encoded 303/448 sequences
# Encoded 304/448 sequences
# Encoded 305/448 sequences
# Encoded 306/448 sequences
# Encoded 307/448 sequences
# Encoded 308/448 sequences
# Encoded 309/448 sequences
# Encoded 310/448 sequences
# Encoded 311/448 sequences
# Encoded 312/448 sequences
# Encoded 313/448 sequences
# Encoded 314/448 sequences
# Encoded 315/448 sequences
# Encoded 316/448 sequences
# Encoded 317/448 sequences
# Encoded 318/448 sequences
# Encoded 319/448 sequences
# Encoded 320/448 sequences
# Encoded 321/448 sequences
# Encoded 322/448 sequences
# Encoded 323/448 sequences
# Encoded 324/448 sequences
# Encoded 325/448 sequences
# Encoded 326/448 sequences
# Encoded 327/448 sequences
# Encoded 328/448 sequences
# Encoded 329/448 sequences
# Encoded 330/448 sequences
# Encoded 331/448 sequences
# Encoded 332/448 sequences
# Encoded 333/448 sequences
# Encoded 334/448 sequences
# Encoded 335/448 sequences
# Encoded 336/448 sequences
# Encoded 337/448 sequences
# Encoded 338/448 sequences
# Encoded 339/448 sequences
# Encoded 340/448 sequences
# Encoded 341/448 sequences
# Encoded 342/448 sequences
# Encoded 343/448 sequences
# Encoded 344/448 sequences
# Encoded 345/448 sequences
# Encoded 346/448 sequences
# Encoded 347/448 sequences
# Encoded 348/448 sequences
# Encoded 349/448 sequences
# Encoded 350/448 sequences
# Encoded 351/448 sequences
# Encoded 352/448 sequences
# Encoded 353/448 sequences
# Encoded 354/448 sequences
# Encoded 355/448 sequences
# Encoded 356/448 sequences
# Encoded 357/448 sequences
# Encoded 358/448 sequences
# Encoded 359/448 sequences
# Encoded 360/448 sequences
# Encoded 361/448 sequences
# Encoded 362/448 sequences
# Encoded 363/448 sequences
# Encoded 364/448 sequences
# Encoded 365/448 sequences
# Encoded 366/448 sequences
# Encoded 367/448 sequences
# Encoded 368/448 sequences
# Encoded 369/448 sequences
# Encoded 370/448 sequences
# Encoded 371/448 sequences
# Encoded 372/448 sequences
# Encoded 373/448 sequences
# Encoded 374/448 sequences
# Encoded 375/448 sequences
# Encoded 376/448 sequences
# Encoded 377/448 sequences
# Encoded 378/448 sequences
# Encoded 379/448 sequences
# Encoded 380/448 sequences
# Encoded 381/448 sequences
# Encoded 382/448 sequences
# Encoded 383/448 sequences
# Encoded 384/448 sequences
# Encoded 385/448 sequences
# Encoded 386/448 sequences
# Encoded 387/448 sequences
# Encoded 388/448 sequences
# Encoded 389/448 sequences
# Encoded 390/448 sequences
# Encoded 391/448 sequences
# Encoded 392/448 sequences
# Encoded 393/448 sequences
# Encoded 394/448 sequences
# Encoded 395/448 sequences
# Encoded 396/448 sequences
# Encoded 397/448 sequences
# Encoded 398/448 sequences
# Encoded 399/448 sequences
# Encoded 400/448 sequences
# Encoded 401/448 sequences
# Encoded 402/448 sequences
# Encoded 403/448 sequences
# Encoded 404/448 sequences
# Encoded 405/448 sequences
# Encoded 406/448 sequences
# Encoded 407/448 sequences
# Encoded 408/448 sequences
# Encoded 409/448 sequences
# Encoded 410/448 sequences
# Encoded 411/448 sequences
# Encoded 412/448 sequences
# Encoded 413/448 sequences
# Encoded 414/448 sequences
# Encoded 415/448 sequences
# Encoded 416/448 sequences
# Encoded 417/448 sequences
# Encoded 418/448 sequences
# Encoded 419/448 sequences
# Encoded 420/448 sequences
# Encoded 421/448 sequences
# Encoded 422/448 sequences
# Encoded 423/448 sequences
# Encoded 424/448 sequences
# Encoded 425/448 sequences
# Encoded 426/448 sequences
# Encoded 427/448 sequences
# Encoded 428/448 sequences
# Encoded 429/448 sequences
# Encoded 430/448 sequences
# Encoded 431/448 sequences
# Encoded 432/448 sequences
# Encoded 433/448 sequences
# Encoded 434/448 sequences
# Encoded 435/448 sequences
# Encoded 436/448 sequences
# Encoded 437/448 sequences
# Encoded 438/448 sequences
# Encoded 439/448 sequences
# Encoded 440/448 sequences
# Encoded 441/448 sequences
# Encoded 442/448 sequences
# Encoded 443/448 sequences
# Encoded 444/448 sequences
# Encoded 445/448 sequences
# Encoded 446/448 sequences
# Encoded 447/448 sequences
# Encoded 448/448 sequences
# 1/1 [==============================] - 1s 864ms/step

# %%
fig, ax = plt.subplots(1,1, figsize=(6, 6), dpi=100)
ax.scatter(pr, tr, color='green', s=25)
ax.set_ylim(-26, 26)
ax.set_xlim(-26, 26)
ax.plot([0, 1], [0, 1], '--', transform=ax.transAxes, color='grey')
ax.set_xlabel('Predicted', size=15)
ax.set_ylabel('True', size=15)
ax.set_title('Predictions for validation set')
# Out:
# Text(0.5, 1.0, 'Predictions for validation set')

# %% [markdown]
# ## Test on PDB

# %%
test_data = pd.read_pickle('../../TCST/hamp_svm/pdb_measure.p')
# usuwanie mutantow
# 3lnr nie jest mutantem, ale bywa problematyczny
test_data.rename(columns={'seq1':'n_seq', 'seq2':'c_seq'}, inplace=True)
test_data=test_data.drop(['5jeq.pdb',
            '5jef.pdb',
            '3zrv.pdb',
            '2lfs.pdb',
            '3zrw.pdb',
            '3zcc.pdb',
            '2l7i.pdb', '2y20.pdb', '2y21.pdb', '2y0q.pdb',
                    
            '3lnr.pdb', 
                    '4i44.pdb', '4i3m.pdb'

           
           ])
test_data['n_seq'] = test_data['n_seq'].apply(lambda x:x[1:-1])
test_data['c_seq'] = test_data['c_seq'].apply(lambda x:x[1:-1])
seq = []
tr = []
for n,r in test_data.iterrows():
    seq.append(r['n_seq'] + r['c_seq'])
    tr.append(np.mean((r['rot'][0::2] + r['rot'][1::2]) / 2)/2)
res = mod.predict(seq)
pr = []
for n,r in res.iterrows():
    pr.append(np.mean(r['N_pred'])/2)
# Out:
# Encoded 1/16 sequences
# Encoded 2/16 sequences
# Encoded 3/16 sequences
# Encoded 4/16 sequences
# Encoded 5/16 sequences
# Encoded 6/16 sequences
# Encoded 7/16 sequences
# Encoded 8/16 sequences
# Encoded 9/16 sequences
# Encoded 10/16 sequences
# Encoded 11/16 sequences
# Encoded 12/16 sequences
# Encoded 13/16 sequences
# Encoded 14/16 sequences
# Encoded 15/16 sequences
# Encoded 16/16 sequences
# Encoded 1/16 sequences
# Encoded 2/16 sequences
# Encoded 3/16 sequences
# Encoded 4/16 sequences
# Encoded 5/16 sequences
# Encoded 6/16 sequences
# Encoded 7/16 sequences
# Encoded 8/16 sequences
# Encoded 9/16 sequences
# Encoded 10/16 sequences
# Encoded 11/16 sequences
# Encoded 12/16 sequences
# Encoded 13/16 sequences
# Encoded 14/16 sequences
# Encoded 15/16 sequences
# Encoded 16/16 sequences
# 1/1 [==============================] - 1s 802ms/step

# %%
fig, ax = plt.subplots(1,1, figsize=(6, 6), dpi=100)
ax.scatter(pr, tr, color='green', s=25)
ax.set_ylim(-26, 26)
ax.set_xlim(-26, 26)
ax.plot([0, 1], [0, 1], '--', transform=ax.transAxes, color='grey')
ax.set_xlabel('Predicted', size=15)
ax.set_ylabel('PDB structure', size=15)
ax.set_title('Predictions for WT HAMPs (with mutants)')
# Out:
# Text(0.5, 1.0, 'Predictions for WT HAMPs (with mutants)')
